# %% [markdown]
# ## Polygon API

# %%
# url = "https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2021-07-22/2021-07-22?adjustedtrue&sort=asc&limit=120&apiKey=a5zA_LXeqkGkDfYI3Ur5nc2tzENS8QVr"

# %%
url = "https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2021-01-01/2021-12-31?adjusted=true&sort=asc&limit=120&apiKey=a5zA_LXeqkGkDfYI3Ur5nc2tzENS8QVr"

# %%
# url = "https: // api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2020-06-01/2020-06-17?apiKey = a5zA_LXeqkGkDfYI3Ur5nc2tzENS8QVr"

# %%
import requests
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
print(r)
# Out:
# <Response [200]>

# %%
r.headers['content-type']
# Out:
# 'application/json'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '{"ticker":"AAPL","queryCount":120,"resultsCount":120,"adjusted":true,"results":[{"v":1.43285672e+08,"vw":129.7326,"o":133.52,"c":129.41,"h":133.6116,"l":126.76,"t":1609736400000,"n":1310217},{"v":9.7664898e+07,"vw":130.7179,"o":128.89,"c":131.01,"h":131.74,"l":128.43,"t":1609822800000,"n":707577},{"v":1.5508797e+08,"vw":128.3502,"o":127.72,"c":126.6,"h":131.0499,"l":126.382,"t":1609909200000,"n":1202574},{"v":1.09578157e+08,"vw":130.1539,"o":128.36,"c":130.92,"h":131.63,"l":127.86,"t":1609995600000,"n":718357},{"v":1.05158245e+08,"vw":131.5657,"o":132.43,"c":132.05,"h":132.63,"l":130.23,"t":1610082000000,"n":800069},{"v":1.0061716e+08,"vw":129.3232,"o":129.19,"c":128.98,"h":130.17,"l":128.5,"t":1610341200000,"n":775027},{"v":9.1851145e+07,"vw":128.4834,"o":128.5,"c":128.8,"h":129.69,"l":126.86,"t":1610427600000,"n":692719},{"v":8.8636831e+07,"vw":130.5588,"o":128.76,"c":130.89,"h":131.45,"l":128.49,"t":1610514000000,"n":596230},{"v":8.9671755e+07,"vw":129.7381,"o":130.8,"c":128.91,"h":131,"l":128.76,"t":1610600400000,"n":651392},{"v":1.11196831e+08,"vw":128.264,"o":128.78,"c":127.14,"h":130.2242,"l":127,"t":1610686800000,"n":713312},{"v":9.0750329e+07,"vw":127.6974,"o":127.78,"c":127.83,"h":128.71,"l":126.938,"t":1611032400000,"n":599768},{"v":1.04134039e+08,"vw":131.4664,"o":128.66,"c":132.03,"h":132.49,"l":128.55,"t":1611118800000,"n":668571},{"v":1.20256319e+08,"vw":135.8584,"o":133.8,"c":136.87,"h":139.67,"l":133.59,"t":1611205200000,"n":834998},{"v":1.1423401e+08,"vw":137.8544,"o":136.28,"c":139.07,"h":139.85,"l":135.02,"t":1611291600000,"n":744041},{"v":1.57588183e+08,"vw":142.6255,"o":143.07,"c":142.92,"h":145.09,"l":136.54,"t":1611550800000,"n":1226813},{"v":9.8390205e+07,"vw":142.8442,"o":143.6,"c":143.16,"h":144.3,"l":141.37,"t":1611637200000,"n":743285},{"v":1.40613944e+08,"vw":142.3522,"o":143.43,"c":142.06,"h":144.3,"l":140.41,"t":1611723600000,"n":1155710},{"v":1.42508399e+08,"vw":139.1841,"o":139.52,"c":137.09,"h":141.99,"l":136.7,"t":1611810000000,"n":1239461},{"v":1.77506312e+08,"vw":132.7372,"o":135.83,"c":131.96,"h":136.74,"l":130.21,"t":1611896400000,"n":1695154},{"v":1.06239823e+08,"vw":133.7923,"o":133.75,"c":134.14,"h":135.38,"l":130.93,"t":1612155600000,"n":924206},{"v":8.3259967e+07,"vw":135.2222,"o":135.73,"c":134.99,"h":136.31,"l":134.61,"t":1612242000000,"n":689676},{"v":8.5880937e+07,"vw":134.6595,"o":135.76,"c":133.94,"h":135.77,"l":133.61,"t":1612328400000,"n":699067},{"v":8.4141061e+07,"vw":136.1869,"o":136.3,"c":137.39,"h":137.4,"l":134.59,"t":1612414800000,"n":658076},{"v":7.530383e+07,"vw":136.6507,"o":137.35,"c":136.76,"h":137.42,"l":135.86,"t":1612501200000,"n":616037},{"v":7.1297214e+07,"vw":136.2094,"o":136.03,"c":136.91,"h":136.96,"l":134.92,"t":1612760400000,"n":614469},{"v":7.6774213e+07,"vw":136.7346,"o":136.62,"c":136.01,"h":137.877,"l":135.85,"t":1612846800000,"n":536824},{"v":7.2546563e+07,"vw":135.4825,"o":136.48,"c":135.39,"h":136.99,"l":134.4,"t":1612933200000,"n":605205},{"v":6.4280029e+07,"vw":134.8643,"o":135.9,"c":135.13,"h":136.39,"l":133.77,"t":1613019600000,"n":547785},{"v":6.013693e+07,"vw":134.5208,"o":134.35,"c":135.37,"h":135.53,"l":133.6921,"t":1613106000000,"n":481804},{"v":8.0576316e+07,"vw":133.8643,"o":135.49,"c":133.19,"h":136.01,"l":132.79,"t":1613451600000,"n":741080},{"v":9.7991849e+07,"vw":130.5913,"o":131.25,"c":130.84,"h":132.22,"l":129.47,"t":1613538000000,"n":971318},{"v":9.6156748e+07,"vw":128.8633,"o":129.2,"c":129.71,"h":129.995,"l":127.41,"t":1613624400000,"n":859568},{"v":8.7340834e+07,"vw":129.766,"o":130.24,"c":129.87,"h":130.71,"l":128.8,"t":1613710800000,"n":683754},{"v":1.03295419e+08,"vw":127.0448,"o":128.01,"c":126,"h":129.72,"l":125.6,"t":1613970000000,"n":969980},{"v":1.58252662e+08,"vw":123.3074,"o":123.76,"c":125.86,"h":126.71,"l":118.39,"t":1614056400000,"n":1547442},{"v":1.10789904e+08,"vw":124.4278,"o":124.94,"c":125.35,"h":125.56,"l":122.23,"t":1614142800000,"n":965716},{"v":1.4819954e+08,"vw":122.6039,"o":124.68,"c":120.99,"h":126.4 ...

# %%
r.json()
# Out:
# {'ticker': 'AAPL',
#  'queryCount': 120,
#  'resultsCount': 120,
#  'adjusted': True,
#  'results': [{'v': 143285672.0,
#    'vw': 129.7326,
#    'o': 133.52,
#    'c': 129.41,
#    'h': 133.6116,
#    'l': 126.76,
#    't': 1609736400000,
#    'n': 1310217},
#   {'v': 97664898.0,
#    'vw': 130.7179,
#    'o': 128.89,
#    'c': 131.01,
#    'h': 131.74,
#    'l': 128.43,
#    't': 1609822800000,
#    'n': 707577},
#   {'v': 155087970.0,
#    'vw': 128.3502,
#    'o': 127.72,
#    'c': 126.6,
#    'h': 131.0499,
#    'l': 126.382,
#    't': 1609909200000,
#    'n': 1202574},
#   {'v': 109578157.0,
#    'vw': 130.1539,
#    'o': 128.36,
#    'c': 130.92,
#    'h': 131.63,
#    'l': 127.86,
#    't': 1609995600000,
#    'n': 718357},
#   {'v': 105158245.0,
#    'vw': 131.5657,
#    'o': 132.43,
#    'c': 132.05,
#    'h': 132.63,
#    'l': 130.23,
#    't': 1610082000000,
#    'n': 800069},
#   {'v': 100617160.0,
#    'vw': 129.3232,
#    'o': 129.19,
#    'c': 128.98,
#    'h': 130.17,
#    'l': 128.5,
#    't': 1610341200000,
#    'n': 775027},
#   {'v': 91851145.0,
#    'vw': 128.4834,
#    'o': 128.5,
#    'c': 128.8,
#    'h': 129.69,
#    'l': 126.86,
#    't': 1610427600000,
#    'n': 692719},
#   {'v': 88636831.0,
#    'vw': 130.5588,
#    'o': 128.76,
#    'c': 130.89,
#    'h': 131.45,
#    'l': 128.49,
#    't': 1610514000000,
#    'n': 596230},
#   {'v': 89671755.0,
#    'vw': 129.7381,
#    'o': 130.8,
#    'c': 128.91,
#    'h': 131,
#    'l': 128.76,
#    't': 1610600400000,
#    'n': 651392},
#   {'v': 111196831.0,
#    'vw': 128.264,
#    'o': 128.78,
#    'c': 127.14,
#    'h': 130.2242,
#    'l': 127,
#    't': 1610686800000,
#    'n': 713312},
#   {'v': 90750329.0,
#    'vw': 127.6974,
#    'o': 127.78,
#    'c': 127.83,
#    'h': 128.71,
#    'l': 126.938,
#    't': 1611032400000,
#    'n': 599768},
#   {'v': 104134039.0,
#    'vw': 131.4664,
#    'o': 128.66,
#    'c': 132.03,
#    'h': 132.49,
#    'l': 128.55,
#    't': 1611118800000,
#    'n': 668571},
#   {'v': 120256319.0,
#    'vw': 135.8584,
#    'o': 133.8,
#    'c': 136.87,
#    'h': 139.67,
#    'l': 133.59,
#    't': 1611205200000,
#    'n': 834998},
#   {'v': 114234010.0,
#    'vw': 137.8544,
#    'o': 136.28,
#    'c': 139.07,
#    'h': 139.85,
#    'l': 135.02,
#    't': 1611291600000,
#    'n': 744041},
#   {'v': 157588183.0,
#    'vw': 142.6255,
#    'o': 143.07,
#    'c': 142.92,
#    'h': 145.09,
#    'l': 136.54,
#    't': 1611550800000,
#    'n': 1226813},
#   {'v': 98390205.0,
#    'vw': 142.8442,
#    'o': 143.6,
#    'c': 143.16,
#    'h': 144.3,
#    'l': 141.37,
#    't': 1611637200000,
#    'n': 743285},
#   {'v': 140613944.0,
#    'vw': 142.3522,
#    'o': 143.43,
#    'c': 142.06,
#    'h': 144.3,
#    'l': 140.41,
#    't': 1611723600000,
#    'n': 1155710},
#   {'v': 142508399.0,
#    'vw': 139.1841,
#    'o': 139.52,
#    'c': 137.09,
#    'h': 141.99,
#    'l': 136.7,
#    't': 1611810000000,
#    'n': 1239461},
#   {'v': 177506312.0,
#    'vw': 132.7372,
#    'o': 135.83,
#    'c': 131.96,
#    'h': 136.74,
#    'l': 130.21,
#    't': 1611896400000,
#    'n': 1695154},
#   {'v': 106239823.0,
#    'vw': 133.7923,
#    'o': 133.75,
#    'c': 134.14,
#    'h': 135.38,
#    'l': 130.93,
#    't': 1612155600000,
#    'n': 924206},
#   {'v': 83259967.0,
#    'vw': 135.2222,
#    'o': 135.73,
#    'c': 134.99,
#    'h': 136.31,
#    'l': 134.61,
#    't': 1612242000000,
#    'n': 689676},
#   {'v': 85880937.0,
#    'vw': 134.6595,
#    'o': 135.76,
#    'c': 133.94,
#    'h': 135.77,
#    'l': 133.61,
#    't': 1612328400000,
#    'n': 699067},
#   {'v': 84141061.0,
#    'vw': 136.1869,
#    'o': 136.3,
#    'c': 137.39,
#    'h': 137.4,
#    'l': 134.59,
#    't': 1612414800000,
#    'n': 658076},
#   {'v': 75303830.0,
#    'vw': 136.6507,
#    'o': 137.35,
#    'c': 136.76,
#    'h': 137.42,
#    'l': 135.86,
#    't': 1612501200000,
#    'n': 616037},
#   {'v': 71297214.0,
#    'vw': 136.2094,
#    'o': 136.03,
#    'c': 136.91,
#    'h': 136.96,
#    'l': 134.92,
#    't': 1612760400000,
#    'n': 614469},
#   {'v': 76774213.0,
#    'vw': 136.7346,
#    'o': 136.62,
#    'c': 136.01,
#    'h': 137.877,
#    'l': 135.85,
#    't': 1612846800000,
#    'n': 536824},
#   {'v': 72546563.0,
#    'vw': 135.4825,
#    'o': 136.48,
#    'c': 135.39,
#    'h': 136.99,
#    'l': 134.4,
#    't': 1612933200000,
#    'n': 605205},
#   {'v': 64280029.0,
#    'vw': 134.8643,
#    'o': 135.9,
#    'c': 135.13,
#    'h': 136.39,
#    'l': 133.77,
#    't': 1613019600000,
#    'n': 547785},
#   {'v': 60136930.0,
#    'vw': 134.5208,
#    'o': 134.35,
#    'c': 135.37,
#    'h': 135.53,
#    'l': 133.6921,
#    't': 1613106000000,
#    'n': 481804},
#   {'v': 80576316.0,
#    'vw': 133.8643,
#    'o': 135.49,
#    'c': 133.19,
#    'h': 136.01,
#    'l': 132.79,
#    't': 1613451600000,
#    'n': 741080},
#   {'v': 97991849.0,
#    'vw': 130.5913,
#    'o': 131.25,
#    'c': 130.84,
#    'h': 132.22,
#    'l': 129.47,
#    't': 1613538000000,
#    'n': 971318},
#   {'v': 96156748.0,
#    'vw': 128.8633,
#    'o': 129.2,
#    'c': 129.71,
#    'h': 129.995,
#    'l': 127.41,
#    't': 1613624400000,
#    'n': 859568},
#   {'v': 87340834.0,
#    'vw': 129.766,
#    'o': 130.24,
#    'c': 129.87,
#    'h': 130.71,
#    'l': 128.8,
#    't': 1613710800000,
#    'n': 683754},
#   {'v': 103295419.0,
#    'vw': 127.0448,
#    'o': 128.01,
#    'c': 126,
#    'h': 129.72,
#    'l': 125.6,
#    't': 1613970000000,
#    'n': 969980},
#   {'v': 158252662.0,
#    'vw': 123.3074,
#    'o': 123.76,
#    'c': 125.86,
#    'h': 126.71,
#    'l': 118.39,
#    't': 1614056400000,
#    'n': 1547442},
#   {'v': 110789904.0,
#    'vw': 124.4278,
#    'o': 124.94,
#    'c': 125.35,
#    'h': 125.56,
#    'l': 122.23,
#    't': 1614142800000,
#    'n': 965716},
#   {'v': 148199540.0,
#    'vw': 122.6039,
#    'o': 124.68,
#    'c': 120.99,
#    'h': 126.4585,
#    'l': 120.54,
#    't': 1614229200000,
#    'n': 1365697},
#   {'v': 164559569.0,
#    'vw': 122.9199,
#    'o': 122.59,
#    'c': 121.26,
#    'h': 124.85,
#    'l': 121.2,
#    't': 1614315600000,
#    'n': 1289339},
#   {'v': 116307892.0,
#    'vw': 126.0528,
#    'o': 123.75,
#    'c': 127.79,
#    'h': 127.93,
#    'l': 122.79,
#    't': 1614574800000,
#    'n': 924487},
#   {'v': 102260945.0,
#    'vw': 126.1136,
#    'o': 128.41,
#    'c': 125.12,
#    'h': 128.72,
#    'l': 125.01,
#    't': 1614661200000,
#    'n': 831904},
#   {'v': 112966340.0,
#    'vw': 123.378,
#    'o': 124.81,
#    'c': 122.06,
#    'h': 125.71,
#    'l': 121.84,
#    't': 1614747600000,
#    'n': 992159},
#   {'v': 178049975.0,
#    'vw': 120.805,
#    'o': 121.75,
#    'c': 120.13,
#    'h': 123.6,
#    'l': 118.62,
#    't': 1614834000000,
#    'n': 1689127},
#   {'v': 153592201.0,
#    'vw': 119.7787,
#    'o': 120.98,
#    'c': 121.42,
#    'h': 121.935,
#    'l': 117.57,
#    't': 1614920400000,
#    'n': 1472273},
#   {'v': 154376610.0,
#    'vw': 117.9393,
#    'o': 120.93,
#    'c': 116.36,
#    'h': 121,
#    'l': 116.21,
#    't': 1615179600000,
#    'n': 1540729},
#   {'v': 129272780.0,
#    'vw': 120.6902,
#    'o': 119.03,
#    'c': 121.085,
#    'h': 122.06,
#    'l': 118.79,
#    't': 1615266000000,
#    'n': 1009102},
#   {'v': 111886327.0,
#    'vw': 120.3297,
#    'o': 121.69,
#    'c': 119.98,
#    'h': 122.17,
#    'l': 119.45,
#    't': 1615352400000,
#    'n': 1031831},
#   {'v': 102991014.0,
#    'vw': 122.0659,
#    'o': 122.54,
#    'c': 121.96,
#    'h': 123.21,
#    'l': 121.26,
#    't': 1615438800000,
#    'n': 790211},
#   {'v': 87955050.0,
#    'vw': 120.2455,
#    'o': 120.4,
#    'c': 121.03,
#    'h': 121.17,
#    'l': 119.16,
#    't': 1615525200000,
#    'n': 762384},
#   {'v': 92568955.0,
#    'vw': 122.9775,
#    'o': 121.41,
#    'c': 123.99,
#    'h': 124,
#    'l': 120.42,
#    't': 1615780800000,
#    'n': 711876},
#   {'v': 115226936.0,
#    'vw': 125.9513,
#    'o': 125.7,
#    'c': 125.57,
#    'h': 127.22,
#    'l': 124.715,
#    't': 1615867200000,
#    'n': 835613},
#   {'v': 111632636.0,
#    'vw': 123.7795,
#    'o': 124.05,
#    'c': 124.76,
#    'h': 125.8599,
#    'l': 122.336,
#    't': 1615953600000,
#    'n': 896781},
#   {'v': 121367255.0,
#    'vw': 121.6504,
#    'o': 122.88,
#    'c': 120.53,
#    'h': 123.18,
#    'l': 120.32,
#    't': 1616040000000,
#    'n': 970641},
#   {'v': 184668022.0,
#    'vw': 120.2005,
#    'o': 119.9,
#    'c': 119.99,
#    'h': 121.43,
#    'l': 119.675,
#    't': 1616126400000,
#    'n': 881988},
#   {'v': 111816184.0,
#    'vw': 122.8192,
#    'o': 120.33,
#    'c': 123.39,
#    'h': 123.87,
#    'l': 120.26,
#    't': 1616385600000,
#    'n': 723652},
#   {'v': 95051142.0,
#    'vw': 122.999,
#    'o': 123.33,
#    'c': 122.54,
#    'h': 124.24,
#    'l': 122.14,
#    't': 1616472000000,
#    'n': 641822},
#   {'v': 88525685.0,
#    'vw': 121.2133,
#    'o': 122.82,
#    'c': 120.09,
#    'h': 122.9,
#    'l': 120.065,
#    't': 1616558400000,
#    'n': 653239},
#   {'v': 98809281.0,
#    'vw': 120.244,
#    'o': 119.54,
#    'c': 120.59,
#    'h': 121.66,
#    'l': 119,
#    't': 1616644800000,
#    'n': 807588},
#   {'v': 94071234.0,
#    'vw': 120.2314,
#    'o': 120.35,
#    'c': 121.21,
#    'h': 121.48,
#    'l': 118.92,
#    't': 1616731200000,
#    'n': 716066},
#   {'v': 80819203.0,
#    'vw': 121.4709,
#    'o': 121.65,
#    'c': 121.39,
#    'h': 122.58,
#    'l': 120.7299,
#    't': 1616990400000,
#    'n': 584885},
#   {'v': 84507919.0,
#    'vw': 119.7036,
#    'o': 120.11,
#    'c': 119.9,
#    'h': 120.4031,
#    'l': 118.86,
#    't': 1617076800000,
#    'n': 667918},
#   {'v': 118323826.0,
#    'vw': 122.6039,
#    'o': 121.65,
#    'c': 122.15,
#    'h': 123.52,
#    'l': 121.15,
#    't': 1617163200000,
#    'n': 740850},
#   {'v': 75089134.0,
#    'vw': 123.1513,
#    'o': 123.66,
#    'c': 123,
#    'h': 124.18,
#    'l': 122.49,
#    't': 1617249600000,
#    'n': 526273},
#   {'v': 88251175.0,
#    'vw': 125.3311,
#    'o': 123.87,
#    'c': 125.9,
#    'h': 126.1601,
#    'l': 123.07,
#    't': 1617595200000,
#    'n': 642630},
#   {'v': 80171253.0,
#    'vw': 126.364,
#    'o': 126.5,
#    'c': 126.21,
#    'h': 127.13,
#    'l': 125.65,
#    't': 1617681600000,
#    'n': 564312},
#   {'v': 83256716.0,
#    'vw': 127.1011,
#    'o': 125.83,
#    'c': 127.9,
#    'h': 127.92,
#    'l': 125.14,
#    't': 1617768000000,
#    'n': 555603},
#   {'v': 88844591.0,
#    'vw': 129.7402,
#    'o': 128.95,
#    'c': 130.36,
#    'h': 130.39,
#    'l': 128.52,
#    't': 1617854400000,
#    'n': 639632},
#   {'v': 106615653.0,
#    'vw': 131.6977,
#    'o': 129.8,
#    'c': 132.995,
#    'h': 133.04,
#    'l': 129.47,
#    't': 1617940800000,
#    'n': 701349},
#   {'v': 91388983.0,
#    'vw': 131.5117,
#    'o': 132.52,
#    'c': 131.24,
#    'h': 132.85,
#    'l': 130.63,
#    't': 1618200000000,
#    'n': 612036},
#   {'v': 90761995.0,
#    'vw': 133.732,
#    'o': 132.44,
#    'c': 134.43,
#    'h': 134.66,
#    'l': 131.93,
#    't': 1618286400000,
#    'n': 640753},
#   {'v': 86222782.0,
#    'vw': 133.0216,
#    'o': 134.94,
#    'c': 132.03,
#    'h': 135,
#    'l': 131.655,
#    't': 1618372800000,
#    'n': 668827},
#   {'v': 89347102.0,
#    'vw': 134.3964,
#    'o': 133.82,
#    'c': 134.5,
#    'h': 135,
#    'l': 133.64,
#    't': 1618459200000,
#    'n': 608980},
#   {'v': 84360386.0,
#    'vw': 134.0367,
#    'o': 134.3,
#    'c': 134.16,
#    'h': 134.67,
#    'l': 133.28,
#    't': 1618545600000,
#    'n': 541233},
#   {'v': 94264215.0,
#    'vw': 134.5998,
#    'o': 133.51,
#    'c': 134.84,
#    'h': 135.47,
#    'l': 133.34,
#    't': 1618804800000,
#    'n': 625255},
#   {'v': 94812249.0,
#    'vw': 133.4438,
#    'o': 135.02,
#    'c': 133.11,
#    'h': 135.53,
#    'l': 131.81,
#    't': 1618891200000,
#    'n': 744673},
#   {'v': 68826135.0,
#    'vw': 132.8647,
#    'o': 132.36,
#    'c': 133.5,
#    'h': 133.75,
#    'l': 131.3001,
#    't': 1618977600000,
#    'n': 508230},
#   {'v': 84566456.0,
#    'vw': 132.7723,
#    'o': 133.04,
#    'c': 131.94,
#    'h': 134.15,
#    'l': 131.41,
#    't': 1619064000000,
#    'n': 615670},
#   {'v': 78666779.0,
#    'vw': 134.1622,
#    'o': 132.16,
#    'c': 134.32,
#    'h': 135.12,
#    'l': 132.16,
#    't': 1619150400000,
#    'n': 519533},
#   {'v': 66888509.0,
#    'vw': 134.5418,
#    'o': 134.83,
#    'c': 134.72,
#    'h': 135.06,
#    'l': 133.56,
#    't': 1619409600000,
#    'n': 484069},
#   {'v': 66015804.0,
#    'vw': 134.5907,
#    'o': 135.01,
#    'c': 134.39,
#    'h': 135.41,
#    'l': 134.11,
#    't': 1619496000000,
#    'n': 480003},
#   {'v': 107746597.0,
#    'vw': 134.6526,
#    'o': 134.31,
#    'c': 133.58,
#    'h': 135.02,
#    'l': 133.08,
#    't': 1619582400000,
#    'n': 783355},
#   {'v': 151100953.0,
#    'vw': 134.1771,
#    'o': 136.47,
#    'c': 133.48,
#    'h': 137.07,
#    'l': 132.45,
#    't': 1619668800000,
#    'n': 1059387},
#   {'v': 109425466.0,
#    'vw': 132.194,
#    'o': 131.78,
#    'c': 131.46,
#    'h': 133.56,
#    'l': 131.065,
#    't': 1619755200000,
#    'n': 701292},
#   {'v': 75135100.0,
#    'vw': 132.8122,
#    'o': 132.04,
#    'c': 132.54,
#    'h': 134.07,
#    'l': 131.83,
#    't': 1620014400000,
#    'n': 580631},
#   {'v': 137544918.0,
#    'vw': 127.9654,
#    'o': 131.19,
#    'c': 127.85,
#    'h': 131.4899,
#    'l': 126.7,
#    't': 1620100800000,
#    'n': 1182700},
#   {'v': 84000900.0,
#    'vw': 129.2267,
#    'o': 129.2,
#    'c': 128.1,
#    'h': 130.45,
#    'l': 127.97,
#    't': 1620187200000,
#    'n': 659279},
#   {'v': 78064334.0,
#    'vw': 128.6316,
#    'o': 127.89,
#    'c': 129.74,
#    'h': 129.75,
#    'l': 127.13,
#    't': 1620273600000,
#    'n': 607088},
#   {'v': 77691273.0,
#    'vw': 130.4433,
#    'o': 130.85,
#    'c': 130.21,
#    'h': 131.2582,
#    'l': 129.475,
#    't': 1620360000000,
#    'n': 545296},
#   {'v': 88071229.0,
#    'vw': 127.8422,
#    'o': 129.41,
#    'c': 126.85,
#    'h': 129.54,
#    'l': 126.81,
#    't': 1620619200000,
#    'n': 680681},
#   {'v': 126142826.0,
#    'vw': 124.7406,
#    'o': 123.5,
#    'c': 125.91,
#    'h': 126.27,
#    'l': 122.77,
#    't': 1620705600000,
#    'n': 922237},
#   {'v': 112172282.0,
#    'vw': 123.0599,
#    'o': 123.4,
#    'c': 122.77,
#    'h': 124.64,
#    'l': 122.25,
#    't': 1620792000000,
#    'n': 876763},
#   {'v': 105850339.0,
#    'vw': 125.1884,
#    'o': 124.58,
#    'c': 124.97,
#    'h': 126.15,
#    'l': 124.26,
#    't': 1620878400000,
#    'n': 788603},
#   {'v': 81872951.0,
#    'vw': 126.9616,
#    'o': 126.25,
#    'c': 127.45,
#    'h': 127.89,
#    'l': 125.85,
#    't': 1620964800000,
#    'n': 535527},
#   {'v': 74216624.0,
#    'vw': 125.9467,
#    'o': 126.82,
#    'c': 126.27,
#    'h': 126.93,
#    'l': 125.17,
#    't': 1621224000000,
#    'n': 502288},
#   {'v': 63342929.0,
#    'vw': 125.9763,
#    'o': 126.56,
#    'c': 124.85,
#    'h': 126.99,
#    'l': 124.78,
#    't': 1621310400000,
#    'n': 493538},
#   {'v': 92593489.0,
#    'vw': 124.0238,
#    'o': 123.16,
#    'c': 124.69,
#    'h': 124.915,
#    'l': 122.86,
#    't': 1621396800000,
#    'n': 674397},
#   {'v': 76852123.0,
#    'vw': 126.8581,
#    'o': 125.23,
#    'c': 127.31,
#    'h': 127.72,
#    'l': 125.1,
#    't': 1621483200000,
#    'n': 494796},
#   {'v': 79295436.0,
#    'vw': 126.1486,
#    'o': 127.82,
#    'c': 125.43,
#    'h': 128,
#    'l': 125.21,
#    't': 1621569600000,
#    'n': 527860},
#   {'v': 63067944.0,
#    'vw': 127.2698,
#    'o': 126.01,
#    'c': 127.1,
#    'h': 127.94,
#    'l': 125.94,
#    't': 1621828800000,
#    'n': 442120},
#   {'v': 72009482.0,
#    'vw': 127.0739,
#    'o': 127.82,
#    'c': 126.9,
#    'h': 128.32,
#    'l': 126.32,
#    't': 1621915200000,
#    'n': 462909},
#   {'v': 56443920.0,
#    'vw': 126.8655,
#    'o': 126.955,
#    'c': 126.85,
#    'h': 127.39,
#    'l': 126.42,
#    't': 1622001600000,
#    'n': 415320},
#   {'v': 94625601.0,
#    'vw': 126.1253,
#    'o': 126.44,
#    'c': 125.28,
#    'h': 127.64,
#    'l': 125.08,
#    't': 1622088000000,
#    'n': 545582},
#   {'v': 71238509.0,
#    'vw': 125.0642,
#    'o': 125.57,
#    'c': 124.61,
#    'h': 125.8,
#    'l': 124.55,
#    't': 1622174400000,
#    'n': 527853},
#   {'v': 65562118.0,
#    'vw': 124.5894,
#    'o': 125.08,
#    'c': 124.28,
#    'h': 125.35,
#    'l': 123.94,
#    't': 1622520000000,
#    'n': 501106},
#   {'v': 58674262.0,
#    'vw': 124.769,
#    'o': 124.28,
#    'c': 125.06,
#    'h': 125.24,
#    'l': 124.05,
#    't': 1622606400000,
#    'n': 461408},
#   {'v': 75699170.0,
#    'vw': 123.7708,
#    'o': 124.68,
#    'c': 123.54,
#    'h': 124.85,
#    'l': 123.13,
#    't': 1622692800000,
#    'n': 562249},
#   {'v': 75169343.0,
#    'vw': 125.368,
#    'o': 124.07,
#    'c': 125.89,
#    'h': 126.16,
#    'l': 123.85,
#    't': 1622779200000,
#    'n': 467760},
#   {'v': 71057550.0,
#    'vw': 125.3691,
#    'o': 126.17,
#    'c': 125.9,
#    'h': 126.32,
#    'l': 124.8321,
#    't': 1623038400000,
#    'n': 504254},
#   {'v': 74403774.0,
#    'vw': 127.0742,
#    'o': 126.6,
#    'c': 126.74,
#    'h': 128.46,
#    'l': 126.2101,
#    't': 1623124800000,
#    'n': 532078},
#   {'v': 56695219.0,
#    'vw': 127.0733,
#    'o': 127.21,
#    'c': 127.13,
#    'h': 127.75,
#    'l': 126.52,
#    't': 1623211200000,
#    'n': 382625},
#   {'v': 71186421.0,
#    'vw': 126.6607,
#    'o': 127.02,
#    'c': 126.11,
#    'h': 128.19,
#    'l': 125.94,
#    't': 1623297600000,
#    'n': 498371},
#   {'v': 53522373.0,
#    'vw': 127.0246,
#    'o': 126.53,
#    'c': 127.35,
#    'h': 127.44,
#    'l': 126.1,
#    't': 1623384000000,
#    'n': 354080},
#   {'v': 96906490.0,
#    'vw': 129.6322,
#    'o': 127.82,
#    'c': 130.48,
#    'h': 130.54,
#    'l': 127.07,
#    't': 1623643200000,
#    'n': 563595},
#   {'v': 62725532.0,
#    'vw': 129.8358,
#    'o': 129.94,
#    'c': 129.64,
#    'h': 130.6,
#    'l': 129.39,
#    't': 1623729600000,
#    'n': 416230},
#   {'v': 91793025.0,
#    'vw': 130.0001,
#    'o': 130.37,
#    'c': 130.15,
#    'h': 130.89,
#    'l': 128.461,
#    't': 1623816000000,
#    'n': 619028},
#   {'v': 96721669.0,
#    'vw': 131.5645,
#    'o': 129.8,
#    'c': 131.79,
#    'h': 132.55,
#    'l': 129.65,
#    't': 1623902400000,
#    'n': 652025},
#   {'v': 108890309.0,
#    'vw': 130.7868,
#    'o': 130.71,
#    'c': 130.46,
#    'h': 131.51,
#    'l': 130.24,
#    't': 1623988800000,
#    'n': 557039},
#   {'v': 79269216.0,
#    'vw': 131.4999,
#    'o': 130.3,
#    'c': 132.3,
#    'h': 132.41,
#    'l': 129.21,
#    't': 1624248000000,
#    'n': 506660},
#   {'v': 73713618.0,
#    'vw': 133.0905,
#    'o': 132.13,
#    'c': 133.98,
#    'h': 134.08,
#    'l': 131.62,
#    't': 1624334400000,
#    'n': 481082},
#   {'v': 60214200.0,
#    'vw': 133.7872,
#    'o': 133.77,
#    'c': 133.7,
#    'h': 134.32,
#    'l': 133.23,
#    't': 1624420800000,
#    'n': 424752},
#   {'v': 68710998.0,
#    'vw': 133.7663,
#    'o': 134.45,
#    'c': 133.41,
#    'h': 134.64,
#    'l': 132.93,
#    't': 1624507200000,
#    'n': 443492}],
#  'status': 'OK',
#  'request_id': 'fa0af544f3bb7d70aa4b48db6d5dd934',
#  'count': 120}

# %%
r.json()
# Out:
# {'ticker': 'AAPL',
#  'queryCount': 120,
#  'resultsCount': 120,
#  'adjusted': True,
#  'results': [{'v': 143285672.0,
#    'vw': 129.7326,
#    'o': 133.52,
#    'c': 129.41,
#    'h': 133.6116,
#    'l': 126.76,
#    't': 1609736400000,
#    'n': 1310217},
#   {'v': 97664898.0,
#    'vw': 130.7179,
#    'o': 128.89,
#    'c': 131.01,
#    'h': 131.74,
#    'l': 128.43,
#    't': 1609822800000,
#    'n': 707577},
#   {'v': 155087970.0,
#    'vw': 128.3502,
#    'o': 127.72,
#    'c': 126.6,
#    'h': 131.0499,
#    'l': 126.382,
#    't': 1609909200000,
#    'n': 1202574},
#   {'v': 109578157.0,
#    'vw': 130.1539,
#    'o': 128.36,
#    'c': 130.92,
#    'h': 131.63,
#    'l': 127.86,
#    't': 1609995600000,
#    'n': 718357},
#   {'v': 105158245.0,
#    'vw': 131.5657,
#    'o': 132.43,
#    'c': 132.05,
#    'h': 132.63,
#    'l': 130.23,
#    't': 1610082000000,
#    'n': 800069},
#   {'v': 100617160.0,
#    'vw': 129.3232,
#    'o': 129.19,
#    'c': 128.98,
#    'h': 130.17,
#    'l': 128.5,
#    't': 1610341200000,
#    'n': 775027},
#   {'v': 91851145.0,
#    'vw': 128.4834,
#    'o': 128.5,
#    'c': 128.8,
#    'h': 129.69,
#    'l': 126.86,
#    't': 1610427600000,
#    'n': 692719},
#   {'v': 88636831.0,
#    'vw': 130.5588,
#    'o': 128.76,
#    'c': 130.89,
#    'h': 131.45,
#    'l': 128.49,
#    't': 1610514000000,
#    'n': 596230},
#   {'v': 89671755.0,
#    'vw': 129.7381,
#    'o': 130.8,
#    'c': 128.91,
#    'h': 131,
#    'l': 128.76,
#    't': 1610600400000,
#    'n': 651392},
#   {'v': 111196831.0,
#    'vw': 128.264,
#    'o': 128.78,
#    'c': 127.14,
#    'h': 130.2242,
#    'l': 127,
#    't': 1610686800000,
#    'n': 713312},
#   {'v': 90750329.0,
#    'vw': 127.6974,
#    'o': 127.78,
#    'c': 127.83,
#    'h': 128.71,
#    'l': 126.938,
#    't': 1611032400000,
#    'n': 599768},
#   {'v': 104134039.0,
#    'vw': 131.4664,
#    'o': 128.66,
#    'c': 132.03,
#    'h': 132.49,
#    'l': 128.55,
#    't': 1611118800000,
#    'n': 668571},
#   {'v': 120256319.0,
#    'vw': 135.8584,
#    'o': 133.8,
#    'c': 136.87,
#    'h': 139.67,
#    'l': 133.59,
#    't': 1611205200000,
#    'n': 834998},
#   {'v': 114234010.0,
#    'vw': 137.8544,
#    'o': 136.28,
#    'c': 139.07,
#    'h': 139.85,
#    'l': 135.02,
#    't': 1611291600000,
#    'n': 744041},
#   {'v': 157588183.0,
#    'vw': 142.6255,
#    'o': 143.07,
#    'c': 142.92,
#    'h': 145.09,
#    'l': 136.54,
#    't': 1611550800000,
#    'n': 1226813},
#   {'v': 98390205.0,
#    'vw': 142.8442,
#    'o': 143.6,
#    'c': 143.16,
#    'h': 144.3,
#    'l': 141.37,
#    't': 1611637200000,
#    'n': 743285},
#   {'v': 140613944.0,
#    'vw': 142.3522,
#    'o': 143.43,
#    'c': 142.06,
#    'h': 144.3,
#    'l': 140.41,
#    't': 1611723600000,
#    'n': 1155710},
#   {'v': 142508399.0,
#    'vw': 139.1841,
#    'o': 139.52,
#    'c': 137.09,
#    'h': 141.99,
#    'l': 136.7,
#    't': 1611810000000,
#    'n': 1239461},
#   {'v': 177506312.0,
#    'vw': 132.7372,
#    'o': 135.83,
#    'c': 131.96,
#    'h': 136.74,
#    'l': 130.21,
#    't': 1611896400000,
#    'n': 1695154},
#   {'v': 106239823.0,
#    'vw': 133.7923,
#    'o': 133.75,
#    'c': 134.14,
#    'h': 135.38,
#    'l': 130.93,
#    't': 1612155600000,
#    'n': 924206},
#   {'v': 83259967.0,
#    'vw': 135.2222,
#    'o': 135.73,
#    'c': 134.99,
#    'h': 136.31,
#    'l': 134.61,
#    't': 1612242000000,
#    'n': 689676},
#   {'v': 85880937.0,
#    'vw': 134.6595,
#    'o': 135.76,
#    'c': 133.94,
#    'h': 135.77,
#    'l': 133.61,
#    't': 1612328400000,
#    'n': 699067},
#   {'v': 84141061.0,
#    'vw': 136.1869,
#    'o': 136.3,
#    'c': 137.39,
#    'h': 137.4,
#    'l': 134.59,
#    't': 1612414800000,
#    'n': 658076},
#   {'v': 75303830.0,
#    'vw': 136.6507,
#    'o': 137.35,
#    'c': 136.76,
#    'h': 137.42,
#    'l': 135.86,
#    't': 1612501200000,
#    'n': 616037},
#   {'v': 71297214.0,
#    'vw': 136.2094,
#    'o': 136.03,
#    'c': 136.91,
#    'h': 136.96,
#    'l': 134.92,
#    't': 1612760400000,
#    'n': 614469},
#   {'v': 76774213.0,
#    'vw': 136.7346,
#    'o': 136.62,
#    'c': 136.01,
#    'h': 137.877,
#    'l': 135.85,
#    't': 1612846800000,
#    'n': 536824},
#   {'v': 72546563.0,
#    'vw': 135.4825,
#    'o': 136.48,
#    'c': 135.39,
#    'h': 136.99,
#    'l': 134.4,
#    't': 1612933200000,
#    'n': 605205},
#   {'v': 64280029.0,
#    'vw': 134.8643,
#    'o': 135.9,
#    'c': 135.13,
#    'h': 136.39,
#    'l': 133.77,
#    't': 1613019600000,
#    'n': 547785},
#   {'v': 60136930.0,
#    'vw': 134.5208,
#    'o': 134.35,
#    'c': 135.37,
#    'h': 135.53,
#    'l': 133.6921,
#    't': 1613106000000,
#    'n': 481804},
#   {'v': 80576316.0,
#    'vw': 133.8643,
#    'o': 135.49,
#    'c': 133.19,
#    'h': 136.01,
#    'l': 132.79,
#    't': 1613451600000,
#    'n': 741080},
#   {'v': 97991849.0,
#    'vw': 130.5913,
#    'o': 131.25,
#    'c': 130.84,
#    'h': 132.22,
#    'l': 129.47,
#    't': 1613538000000,
#    'n': 971318},
#   {'v': 96156748.0,
#    'vw': 128.8633,
#    'o': 129.2,
#    'c': 129.71,
#    'h': 129.995,
#    'l': 127.41,
#    't': 1613624400000,
#    'n': 859568},
#   {'v': 87340834.0,
#    'vw': 129.766,
#    'o': 130.24,
#    'c': 129.87,
#    'h': 130.71,
#    'l': 128.8,
#    't': 1613710800000,
#    'n': 683754},
#   {'v': 103295419.0,
#    'vw': 127.0448,
#    'o': 128.01,
#    'c': 126,
#    'h': 129.72,
#    'l': 125.6,
#    't': 1613970000000,
#    'n': 969980},
#   {'v': 158252662.0,
#    'vw': 123.3074,
#    'o': 123.76,
#    'c': 125.86,
#    'h': 126.71,
#    'l': 118.39,
#    't': 1614056400000,
#    'n': 1547442},
#   {'v': 110789904.0,
#    'vw': 124.4278,
#    'o': 124.94,
#    'c': 125.35,
#    'h': 125.56,
#    'l': 122.23,
#    't': 1614142800000,
#    'n': 965716},
#   {'v': 148199540.0,
#    'vw': 122.6039,
#    'o': 124.68,
#    'c': 120.99,
#    'h': 126.4585,
#    'l': 120.54,
#    't': 1614229200000,
#    'n': 1365697},
#   {'v': 164559569.0,
#    'vw': 122.9199,
#    'o': 122.59,
#    'c': 121.26,
#    'h': 124.85,
#    'l': 121.2,
#    't': 1614315600000,
#    'n': 1289339},
#   {'v': 116307892.0,
#    'vw': 126.0528,
#    'o': 123.75,
#    'c': 127.79,
#    'h': 127.93,
#    'l': 122.79,
#    't': 1614574800000,
#    'n': 924487},
#   {'v': 102260945.0,
#    'vw': 126.1136,
#    'o': 128.41,
#    'c': 125.12,
#    'h': 128.72,
#    'l': 125.01,
#    't': 1614661200000,
#    'n': 831904},
#   {'v': 112966340.0,
#    'vw': 123.378,
#    'o': 124.81,
#    'c': 122.06,
#    'h': 125.71,
#    'l': 121.84,
#    't': 1614747600000,
#    'n': 992159},
#   {'v': 178049975.0,
#    'vw': 120.805,
#    'o': 121.75,
#    'c': 120.13,
#    'h': 123.6,
#    'l': 118.62,
#    't': 1614834000000,
#    'n': 1689127},
#   {'v': 153592201.0,
#    'vw': 119.7787,
#    'o': 120.98,
#    'c': 121.42,
#    'h': 121.935,
#    'l': 117.57,
#    't': 1614920400000,
#    'n': 1472273},
#   {'v': 154376610.0,
#    'vw': 117.9393,
#    'o': 120.93,
#    'c': 116.36,
#    'h': 121,
#    'l': 116.21,
#    't': 1615179600000,
#    'n': 1540729},
#   {'v': 129272780.0,
#    'vw': 120.6902,
#    'o': 119.03,
#    'c': 121.085,
#    'h': 122.06,
#    'l': 118.79,
#    't': 1615266000000,
#    'n': 1009102},
#   {'v': 111886327.0,
#    'vw': 120.3297,
#    'o': 121.69,
#    'c': 119.98,
#    'h': 122.17,
#    'l': 119.45,
#    't': 1615352400000,
#    'n': 1031831},
#   {'v': 102991014.0,
#    'vw': 122.0659,
#    'o': 122.54,
#    'c': 121.96,
#    'h': 123.21,
#    'l': 121.26,
#    't': 1615438800000,
#    'n': 790211},
#   {'v': 87955050.0,
#    'vw': 120.2455,
#    'o': 120.4,
#    'c': 121.03,
#    'h': 121.17,
#    'l': 119.16,
#    't': 1615525200000,
#    'n': 762384},
#   {'v': 92568955.0,
#    'vw': 122.9775,
#    'o': 121.41,
#    'c': 123.99,
#    'h': 124,
#    'l': 120.42,
#    't': 1615780800000,
#    'n': 711876},
#   {'v': 115226936.0,
#    'vw': 125.9513,
#    'o': 125.7,
#    'c': 125.57,
#    'h': 127.22,
#    'l': 124.715,
#    't': 1615867200000,
#    'n': 835613},
#   {'v': 111632636.0,
#    'vw': 123.7795,
#    'o': 124.05,
#    'c': 124.76,
#    'h': 125.8599,
#    'l': 122.336,
#    't': 1615953600000,
#    'n': 896781},
#   {'v': 121367255.0,
#    'vw': 121.6504,
#    'o': 122.88,
#    'c': 120.53,
#    'h': 123.18,
#    'l': 120.32,
#    't': 1616040000000,
#    'n': 970641},
#   {'v': 184668022.0,
#    'vw': 120.2005,
#    'o': 119.9,
#    'c': 119.99,
#    'h': 121.43,
#    'l': 119.675,
#    't': 1616126400000,
#    'n': 881988},
#   {'v': 111816184.0,
#    'vw': 122.8192,
#    'o': 120.33,
#    'c': 123.39,
#    'h': 123.87,
#    'l': 120.26,
#    't': 1616385600000,
#    'n': 723652},
#   {'v': 95051142.0,
#    'vw': 122.999,
#    'o': 123.33,
#    'c': 122.54,
#    'h': 124.24,
#    'l': 122.14,
#    't': 1616472000000,
#    'n': 641822},
#   {'v': 88525685.0,
#    'vw': 121.2133,
#    'o': 122.82,
#    'c': 120.09,
#    'h': 122.9,
#    'l': 120.065,
#    't': 1616558400000,
#    'n': 653239},
#   {'v': 98809281.0,
#    'vw': 120.244,
#    'o': 119.54,
#    'c': 120.59,
#    'h': 121.66,
#    'l': 119,
#    't': 1616644800000,
#    'n': 807588},
#   {'v': 94071234.0,
#    'vw': 120.2314,
#    'o': 120.35,
#    'c': 121.21,
#    'h': 121.48,
#    'l': 118.92,
#    't': 1616731200000,
#    'n': 716066},
#   {'v': 80819203.0,
#    'vw': 121.4709,
#    'o': 121.65,
#    'c': 121.39,
#    'h': 122.58,
#    'l': 120.7299,
#    't': 1616990400000,
#    'n': 584885},
#   {'v': 84507919.0,
#    'vw': 119.7036,
#    'o': 120.11,
#    'c': 119.9,
#    'h': 120.4031,
#    'l': 118.86,
#    't': 1617076800000,
#    'n': 667918},
#   {'v': 118323826.0,
#    'vw': 122.6039,
#    'o': 121.65,
#    'c': 122.15,
#    'h': 123.52,
#    'l': 121.15,
#    't': 1617163200000,
#    'n': 740850},
#   {'v': 75089134.0,
#    'vw': 123.1513,
#    'o': 123.66,
#    'c': 123,
#    'h': 124.18,
#    'l': 122.49,
#    't': 1617249600000,
#    'n': 526273},
#   {'v': 88251175.0,
#    'vw': 125.3311,
#    'o': 123.87,
#    'c': 125.9,
#    'h': 126.1601,
#    'l': 123.07,
#    't': 1617595200000,
#    'n': 642630},
#   {'v': 80171253.0,
#    'vw': 126.364,
#    'o': 126.5,
#    'c': 126.21,
#    'h': 127.13,
#    'l': 125.65,
#    't': 1617681600000,
#    'n': 564312},
#   {'v': 83256716.0,
#    'vw': 127.1011,
#    'o': 125.83,
#    'c': 127.9,
#    'h': 127.92,
#    'l': 125.14,
#    't': 1617768000000,
#    'n': 555603},
#   {'v': 88844591.0,
#    'vw': 129.7402,
#    'o': 128.95,
#    'c': 130.36,
#    'h': 130.39,
#    'l': 128.52,
#    't': 1617854400000,
#    'n': 639632},
#   {'v': 106615653.0,
#    'vw': 131.6977,
#    'o': 129.8,
#    'c': 132.995,
#    'h': 133.04,
#    'l': 129.47,
#    't': 1617940800000,
#    'n': 701349},
#   {'v': 91388983.0,
#    'vw': 131.5117,
#    'o': 132.52,
#    'c': 131.24,
#    'h': 132.85,
#    'l': 130.63,
#    't': 1618200000000,
#    'n': 612036},
#   {'v': 90761995.0,
#    'vw': 133.732,
#    'o': 132.44,
#    'c': 134.43,
#    'h': 134.66,
#    'l': 131.93,
#    't': 1618286400000,
#    'n': 640753},
#   {'v': 86222782.0,
#    'vw': 133.0216,
#    'o': 134.94,
#    'c': 132.03,
#    'h': 135,
#    'l': 131.655,
#    't': 1618372800000,
#    'n': 668827},
#   {'v': 89347102.0,
#    'vw': 134.3964,
#    'o': 133.82,
#    'c': 134.5,
#    'h': 135,
#    'l': 133.64,
#    't': 1618459200000,
#    'n': 608980},
#   {'v': 84360386.0,
#    'vw': 134.0367,
#    'o': 134.3,
#    'c': 134.16,
#    'h': 134.67,
#    'l': 133.28,
#    't': 1618545600000,
#    'n': 541233},
#   {'v': 94264215.0,
#    'vw': 134.5998,
#    'o': 133.51,
#    'c': 134.84,
#    'h': 135.47,
#    'l': 133.34,
#    't': 1618804800000,
#    'n': 625255},
#   {'v': 94812249.0,
#    'vw': 133.4438,
#    'o': 135.02,
#    'c': 133.11,
#    'h': 135.53,
#    'l': 131.81,
#    't': 1618891200000,
#    'n': 744673},
#   {'v': 68826135.0,
#    'vw': 132.8647,
#    'o': 132.36,
#    'c': 133.5,
#    'h': 133.75,
#    'l': 131.3001,
#    't': 1618977600000,
#    'n': 508230},
#   {'v': 84566456.0,
#    'vw': 132.7723,
#    'o': 133.04,
#    'c': 131.94,
#    'h': 134.15,
#    'l': 131.41,
#    't': 1619064000000,
#    'n': 615670},
#   {'v': 78666779.0,
#    'vw': 134.1622,
#    'o': 132.16,
#    'c': 134.32,
#    'h': 135.12,
#    'l': 132.16,
#    't': 1619150400000,
#    'n': 519533},
#   {'v': 66888509.0,
#    'vw': 134.5418,
#    'o': 134.83,
#    'c': 134.72,
#    'h': 135.06,
#    'l': 133.56,
#    't': 1619409600000,
#    'n': 484069},
#   {'v': 66015804.0,
#    'vw': 134.5907,
#    'o': 135.01,
#    'c': 134.39,
#    'h': 135.41,
#    'l': 134.11,
#    't': 1619496000000,
#    'n': 480003},
#   {'v': 107746597.0,
#    'vw': 134.6526,
#    'o': 134.31,
#    'c': 133.58,
#    'h': 135.02,
#    'l': 133.08,
#    't': 1619582400000,
#    'n': 783355},
#   {'v': 151100953.0,
#    'vw': 134.1771,
#    'o': 136.47,
#    'c': 133.48,
#    'h': 137.07,
#    'l': 132.45,
#    't': 1619668800000,
#    'n': 1059387},
#   {'v': 109425466.0,
#    'vw': 132.194,
#    'o': 131.78,
#    'c': 131.46,
#    'h': 133.56,
#    'l': 131.065,
#    't': 1619755200000,
#    'n': 701292},
#   {'v': 75135100.0,
#    'vw': 132.8122,
#    'o': 132.04,
#    'c': 132.54,
#    'h': 134.07,
#    'l': 131.83,
#    't': 1620014400000,
#    'n': 580631},
#   {'v': 137544918.0,
#    'vw': 127.9654,
#    'o': 131.19,
#    'c': 127.85,
#    'h': 131.4899,
#    'l': 126.7,
#    't': 1620100800000,
#    'n': 1182700},
#   {'v': 84000900.0,
#    'vw': 129.2267,
#    'o': 129.2,
#    'c': 128.1,
#    'h': 130.45,
#    'l': 127.97,
#    't': 1620187200000,
#    'n': 659279},
#   {'v': 78064334.0,
#    'vw': 128.6316,
#    'o': 127.89,
#    'c': 129.74,
#    'h': 129.75,
#    'l': 127.13,
#    't': 1620273600000,
#    'n': 607088},
#   {'v': 77691273.0,
#    'vw': 130.4433,
#    'o': 130.85,
#    'c': 130.21,
#    'h': 131.2582,
#    'l': 129.475,
#    't': 1620360000000,
#    'n': 545296},
#   {'v': 88071229.0,
#    'vw': 127.8422,
#    'o': 129.41,
#    'c': 126.85,
#    'h': 129.54,
#    'l': 126.81,
#    't': 1620619200000,
#    'n': 680681},
#   {'v': 126142826.0,
#    'vw': 124.7406,
#    'o': 123.5,
#    'c': 125.91,
#    'h': 126.27,
#    'l': 122.77,
#    't': 1620705600000,
#    'n': 922237},
#   {'v': 112172282.0,
#    'vw': 123.0599,
#    'o': 123.4,
#    'c': 122.77,
#    'h': 124.64,
#    'l': 122.25,
#    't': 1620792000000,
#    'n': 876763},
#   {'v': 105850339.0,
#    'vw': 125.1884,
#    'o': 124.58,
#    'c': 124.97,
#    'h': 126.15,
#    'l': 124.26,
#    't': 1620878400000,
#    'n': 788603},
#   {'v': 81872951.0,
#    'vw': 126.9616,
#    'o': 126.25,
#    'c': 127.45,
#    'h': 127.89,
#    'l': 125.85,
#    't': 1620964800000,
#    'n': 535527},
#   {'v': 74216624.0,
#    'vw': 125.9467,
#    'o': 126.82,
#    'c': 126.27,
#    'h': 126.93,
#    'l': 125.17,
#    't': 1621224000000,
#    'n': 502288},
#   {'v': 63342929.0,
#    'vw': 125.9763,
#    'o': 126.56,
#    'c': 124.85,
#    'h': 126.99,
#    'l': 124.78,
#    't': 1621310400000,
#    'n': 493538},
#   {'v': 92593489.0,
#    'vw': 124.0238,
#    'o': 123.16,
#    'c': 124.69,
#    'h': 124.915,
#    'l': 122.86,
#    't': 1621396800000,
#    'n': 674397},
#   {'v': 76852123.0,
#    'vw': 126.8581,
#    'o': 125.23,
#    'c': 127.31,
#    'h': 127.72,
#    'l': 125.1,
#    't': 1621483200000,
#    'n': 494796},
#   {'v': 79295436.0,
#    'vw': 126.1486,
#    'o': 127.82,
#    'c': 125.43,
#    'h': 128,
#    'l': 125.21,
#    't': 1621569600000,
#    'n': 527860},
#   {'v': 63067944.0,
#    'vw': 127.2698,
#    'o': 126.01,
#    'c': 127.1,
#    'h': 127.94,
#    'l': 125.94,
#    't': 1621828800000,
#    'n': 442120},
#   {'v': 72009482.0,
#    'vw': 127.0739,
#    'o': 127.82,
#    'c': 126.9,
#    'h': 128.32,
#    'l': 126.32,
#    't': 1621915200000,
#    'n': 462909},
#   {'v': 56443920.0,
#    'vw': 126.8655,
#    'o': 126.955,
#    'c': 126.85,
#    'h': 127.39,
#    'l': 126.42,
#    't': 1622001600000,
#    'n': 415320},
#   {'v': 94625601.0,
#    'vw': 126.1253,
#    'o': 126.44,
#    'c': 125.28,
#    'h': 127.64,
#    'l': 125.08,
#    't': 1622088000000,
#    'n': 545582},
#   {'v': 71238509.0,
#    'vw': 125.0642,
#    'o': 125.57,
#    'c': 124.61,
#    'h': 125.8,
#    'l': 124.55,
#    't': 1622174400000,
#    'n': 527853},
#   {'v': 65562118.0,
#    'vw': 124.5894,
#    'o': 125.08,
#    'c': 124.28,
#    'h': 125.35,
#    'l': 123.94,
#    't': 1622520000000,
#    'n': 501106},
#   {'v': 58674262.0,
#    'vw': 124.769,
#    'o': 124.28,
#    'c': 125.06,
#    'h': 125.24,
#    'l': 124.05,
#    't': 1622606400000,
#    'n': 461408},
#   {'v': 75699170.0,
#    'vw': 123.7708,
#    'o': 124.68,
#    'c': 123.54,
#    'h': 124.85,
#    'l': 123.13,
#    't': 1622692800000,
#    'n': 562249},
#   {'v': 75169343.0,
#    'vw': 125.368,
#    'o': 124.07,
#    'c': 125.89,
#    'h': 126.16,
#    'l': 123.85,
#    't': 1622779200000,
#    'n': 467760},
#   {'v': 71057550.0,
#    'vw': 125.3691,
#    'o': 126.17,
#    'c': 125.9,
#    'h': 126.32,
#    'l': 124.8321,
#    't': 1623038400000,
#    'n': 504254},
#   {'v': 74403774.0,
#    'vw': 127.0742,
#    'o': 126.6,
#    'c': 126.74,
#    'h': 128.46,
#    'l': 126.2101,
#    't': 1623124800000,
#    'n': 532078},
#   {'v': 56695219.0,
#    'vw': 127.0733,
#    'o': 127.21,
#    'c': 127.13,
#    'h': 127.75,
#    'l': 126.52,
#    't': 1623211200000,
#    'n': 382625},
#   {'v': 71186421.0,
#    'vw': 126.6607,
#    'o': 127.02,
#    'c': 126.11,
#    'h': 128.19,
#    'l': 125.94,
#    't': 1623297600000,
#    'n': 498371},
#   {'v': 53522373.0,
#    'vw': 127.0246,
#    'o': 126.53,
#    'c': 127.35,
#    'h': 127.44,
#    'l': 126.1,
#    't': 1623384000000,
#    'n': 354080},
#   {'v': 96906490.0,
#    'vw': 129.6322,
#    'o': 127.82,
#    'c': 130.48,
#    'h': 130.54,
#    'l': 127.07,
#    't': 1623643200000,
#    'n': 563595},
#   {'v': 62725532.0,
#    'vw': 129.8358,
#    'o': 129.94,
#    'c': 129.64,
#    'h': 130.6,
#    'l': 129.39,
#    't': 1623729600000,
#    'n': 416230},
#   {'v': 91793025.0,
#    'vw': 130.0001,
#    'o': 130.37,
#    'c': 130.15,
#    'h': 130.89,
#    'l': 128.461,
#    't': 1623816000000,
#    'n': 619028},
#   {'v': 96721669.0,
#    'vw': 131.5645,
#    'o': 129.8,
#    'c': 131.79,
#    'h': 132.55,
#    'l': 129.65,
#    't': 1623902400000,
#    'n': 652025},
#   {'v': 108890309.0,
#    'vw': 130.7868,
#    'o': 130.71,
#    'c': 130.46,
#    'h': 131.51,
#    'l': 130.24,
#    't': 1623988800000,
#    'n': 557039},
#   {'v': 79269216.0,
#    'vw': 131.4999,
#    'o': 130.3,
#    'c': 132.3,
#    'h': 132.41,
#    'l': 129.21,
#    't': 1624248000000,
#    'n': 506660},
#   {'v': 73713618.0,
#    'vw': 133.0905,
#    'o': 132.13,
#    'c': 133.98,
#    'h': 134.08,
#    'l': 131.62,
#    't': 1624334400000,
#    'n': 481082},
#   {'v': 60214200.0,
#    'vw': 133.7872,
#    'o': 133.77,
#    'c': 133.7,
#    'h': 134.32,
#    'l': 133.23,
#    't': 1624420800000,
#    'n': 424752},
#   {'v': 68710998.0,
#    'vw': 133.7663,
#    'o': 134.45,
#    'c': 133.41,
#    'h': 134.64,
#    'l': 132.93,
#    't': 1624507200000,
#    'n': 443492}],
#  'status': 'OK',
#  'request_id': 'fa0af544f3bb7d70aa4b48db6d5dd934',
#  'count': 120}

# %%
text = r.json()

# %%
text['ticker']
# Out:
# 'AAPL'

# %%
for item in text:
    print(f'{item}: {text[item]}')
# Out:
# ticker: AAPL
# queryCount: 120
# resultsCount: 120
# adjusted: True
# results: [{'v': 143285672.0, 'vw': 129.7326, 'o': 133.52, 'c': 129.41, 'h': 133.6116, 'l': 126.76, 't': 1609736400000, 'n': 1310217}, {'v': 97664898.0, 'vw': 130.7179, 'o': 128.89, 'c': 131.01, 'h': 131.74, 'l': 128.43, 't': 1609822800000, 'n': 707577}, {'v': 155087970.0, 'vw': 128.3502, 'o': 127.72, 'c': 126.6, 'h': 131.0499, 'l': 126.382, 't': 1609909200000, 'n': 1202574}, {'v': 109578157.0, 'vw': 130.1539, 'o': 128.36, 'c': 130.92, 'h': 131.63, 'l': 127.86, 't': 1609995600000, 'n': 718357}, {'v': 105158245.0, 'vw': 131.5657, 'o': 132.43, 'c': 132.05, 'h': 132.63, 'l': 130.23, 't': 1610082000000, 'n': 800069}, {'v': 100617160.0, 'vw': 129.3232, 'o': 129.19, 'c': 128.98, 'h': 130.17, 'l': 128.5, 't': 1610341200000, 'n': 775027}, {'v': 91851145.0, 'vw': 128.4834, 'o': 128.5, 'c': 128.8, 'h': 129.69, 'l': 126.86, 't': 1610427600000, 'n': 692719}, {'v': 88636831.0, 'vw': 130.5588, 'o': 128.76, 'c': 130.89, 'h': 131.45, 'l': 128.49, 't': 1610514000000, 'n': 596230}, {'v': 89671755.0, 'vw': 129.7381, 'o': 130.8, 'c': 128.91, 'h': 131, 'l': 128.76, 't': 1610600400000, 'n': 651392}, {'v': 111196831.0, 'vw': 128.264, 'o': 128.78, 'c': 127.14, 'h': 130.2242, 'l': 127, 't': 1610686800000, 'n': 713312}, {'v': 90750329.0, 'vw': 127.6974, 'o': 127.78, 'c': 127.83, 'h': 128.71, 'l': 126.938, 't': 1611032400000, 'n': 599768}, {'v': 104134039.0, 'vw': 131.4664, 'o': 128.66, 'c': 132.03, 'h': 132.49, 'l': 128.55, 't': 1611118800000, 'n': 668571}, {'v': 120256319.0, 'vw': 135.8584, 'o': 133.8, 'c': 136.87, 'h': 139.67, 'l': 133.59, 't': 1611205200000, 'n': 834998}, {'v': 114234010.0, 'vw': 137.8544, 'o': 136.28, 'c': 139.07, 'h': 139.85, 'l': 135.02, 't': 1611291600000, 'n': 744041}, {'v': 157588183.0, 'vw': 142.6255, 'o': 143.07, 'c': 142.92, 'h': 145.09, 'l': 136.54, 't': 1611550800000, 'n': 1226813}, {'v': 98390205.0, 'vw': 142.8442, 'o': 143.6, 'c': 143.16, 'h': 144.3, 'l': 141.37, 't': 1611637200000, 'n': 743285}, {'v': 140613944.0, 'vw': 142.3522, 'o': 143.43, 'c': 142.06, 'h': 144.3, 'l': 140.41, 't': 1611723600000, 'n': 1155710}, {'v': 142508399.0, 'vw': 139.1841, 'o': 139.52, 'c': 137.09, 'h': 141.99, 'l': 136.7, 't': 1611810000000, 'n': 1239461}, {'v': 177506312.0, 'vw': 132.7372, 'o': 135.83, 'c': 131.96, 'h': 136.74, 'l': 130.21, 't': 1611896400000, 'n': 1695154}, {'v': 106239823.0, 'vw': 133.7923, 'o': 133.75, 'c': 134.14, 'h': 135.38, 'l': 130.93, 't': 1612155600000, 'n': 924206}, {'v': 83259967.0, 'vw': 135.2222, 'o': 135.73, 'c': 134.99, 'h': 136.31, 'l': 134.61, 't': 1612242000000, 'n': 689676}, {'v': 85880937.0, 'vw': 134.6595, 'o': 135.76, 'c': 133.94, 'h': 135.77, 'l': 133.61, 't': 1612328400000, 'n': 699067}, {'v': 84141061.0, 'vw': 136.1869, 'o': 136.3, 'c': 137.39, 'h': 137.4, 'l': 134.59, 't': 1612414800000, 'n': 658076}, {'v': 75303830.0, 'vw': 136.6507, 'o': 137.35, 'c': 136.76, 'h': 137.42, 'l': 135.86, 't': 1612501200000, 'n': 616037}, {'v': 71297214.0, 'vw': 136.2094, 'o': 136.03, 'c': 136.91, 'h': 136.96, 'l': 134.92, 't': 1612760400000, 'n': 614469}, {'v': 76774213.0, 'vw': 136.7346, 'o': 136.62, 'c': 136.01, 'h': 137.877, 'l': 135.85, 't': 1612846800000, 'n': 536824}, {'v': 72546563.0, 'vw': 135.4825, 'o': 136.48, 'c': 135.39, 'h': 136.99, 'l': 134.4, 't': 1612933200000, 'n': 605205}, {'v': 64280029.0, 'vw': 134.8643, 'o': 135.9, 'c': 135.13, 'h': 136.39, 'l': 133.77, 't': 1613019600000, 'n': 547785}, {'v': 60136930.0, 'vw': 134.5208, 'o': 134.35, 'c': 135.37, 'h': 135.53, 'l': 133.6921, 't': 1613106000000, 'n': 481804}, {'v': 80576316.0, 'vw': 133.8643, 'o': 135.49, 'c': 133.19, 'h': 136.01, 'l': 132.79, 't': 1613451600000, 'n': 741080}, {'v': 97991849.0, 'vw': 130.5913, 'o': 131.25, 'c': 130.84, 'h': 132.22, 'l': 129.47, 't': 1613538000000, 'n': 971318}, {'v': 96156748.0, 'vw': 128.8633, 'o': 129.2, 'c': 129.71, 'h': 129.995, 'l': 127.41, 't': 1613624400000, 'n': 859568}, {'v': 87340834.0, 'vw': 129.766, 'o': 130.24, 'c': 129.87, 'h': 130.71, 'l': 128.8, 't': 1613710800000, 'n': 683754}, {'v': 103295419.0, 'vw ...
# status: OK
# request_id: fa0af544f3bb7d70aa4b48db6d5dd934
# count: 120

# %%
for item in text['results'][0]:
    print(f'{item}:')
# Out:
# v:
# vw:
# o:
# c:
# h:
# l:
# t:
# n:

# %%
text['results']
# Out:
# [{'v': 143285672.0,
#   'vw': 129.7326,
#   'o': 133.52,
#   'c': 129.41,
#   'h': 133.6116,
#   'l': 126.76,
#   't': 1609736400000,
#   'n': 1310217},
#  {'v': 97664898.0,
#   'vw': 130.7179,
#   'o': 128.89,
#   'c': 131.01,
#   'h': 131.74,
#   'l': 128.43,
#   't': 1609822800000,
#   'n': 707577},
#  {'v': 155087970.0,
#   'vw': 128.3502,
#   'o': 127.72,
#   'c': 126.6,
#   'h': 131.0499,
#   'l': 126.382,
#   't': 1609909200000,
#   'n': 1202574},
#  {'v': 109578157.0,
#   'vw': 130.1539,
#   'o': 128.36,
#   'c': 130.92,
#   'h': 131.63,
#   'l': 127.86,
#   't': 1609995600000,
#   'n': 718357},
#  {'v': 105158245.0,
#   'vw': 131.5657,
#   'o': 132.43,
#   'c': 132.05,
#   'h': 132.63,
#   'l': 130.23,
#   't': 1610082000000,
#   'n': 800069},
#  {'v': 100617160.0,
#   'vw': 129.3232,
#   'o': 129.19,
#   'c': 128.98,
#   'h': 130.17,
#   'l': 128.5,
#   't': 1610341200000,
#   'n': 775027},
#  {'v': 91851145.0,
#   'vw': 128.4834,
#   'o': 128.5,
#   'c': 128.8,
#   'h': 129.69,
#   'l': 126.86,
#   't': 1610427600000,
#   'n': 692719},
#  {'v': 88636831.0,
#   'vw': 130.5588,
#   'o': 128.76,
#   'c': 130.89,
#   'h': 131.45,
#   'l': 128.49,
#   't': 1610514000000,
#   'n': 596230},
#  {'v': 89671755.0,
#   'vw': 129.7381,
#   'o': 130.8,
#   'c': 128.91,
#   'h': 131,
#   'l': 128.76,
#   't': 1610600400000,
#   'n': 651392},
#  {'v': 111196831.0,
#   'vw': 128.264,
#   'o': 128.78,
#   'c': 127.14,
#   'h': 130.2242,
#   'l': 127,
#   't': 1610686800000,
#   'n': 713312},
#  {'v': 90750329.0,
#   'vw': 127.6974,
#   'o': 127.78,
#   'c': 127.83,
#   'h': 128.71,
#   'l': 126.938,
#   't': 1611032400000,
#   'n': 599768},
#  {'v': 104134039.0,
#   'vw': 131.4664,
#   'o': 128.66,
#   'c': 132.03,
#   'h': 132.49,
#   'l': 128.55,
#   't': 1611118800000,
#   'n': 668571},
#  {'v': 120256319.0,
#   'vw': 135.8584,
#   'o': 133.8,
#   'c': 136.87,
#   'h': 139.67,
#   'l': 133.59,
#   't': 1611205200000,
#   'n': 834998},
#  {'v': 114234010.0,
#   'vw': 137.8544,
#   'o': 136.28,
#   'c': 139.07,
#   'h': 139.85,
#   'l': 135.02,
#   't': 1611291600000,
#   'n': 744041},
#  {'v': 157588183.0,
#   'vw': 142.6255,
#   'o': 143.07,
#   'c': 142.92,
#   'h': 145.09,
#   'l': 136.54,
#   't': 1611550800000,
#   'n': 1226813},
#  {'v': 98390205.0,
#   'vw': 142.8442,
#   'o': 143.6,
#   'c': 143.16,
#   'h': 144.3,
#   'l': 141.37,
#   't': 1611637200000,
#   'n': 743285},
#  {'v': 140613944.0,
#   'vw': 142.3522,
#   'o': 143.43,
#   'c': 142.06,
#   'h': 144.3,
#   'l': 140.41,
#   't': 1611723600000,
#   'n': 1155710},
#  {'v': 142508399.0,
#   'vw': 139.1841,
#   'o': 139.52,
#   'c': 137.09,
#   'h': 141.99,
#   'l': 136.7,
#   't': 1611810000000,
#   'n': 1239461},
#  {'v': 177506312.0,
#   'vw': 132.7372,
#   'o': 135.83,
#   'c': 131.96,
#   'h': 136.74,
#   'l': 130.21,
#   't': 1611896400000,
#   'n': 1695154},
#  {'v': 106239823.0,
#   'vw': 133.7923,
#   'o': 133.75,
#   'c': 134.14,
#   'h': 135.38,
#   'l': 130.93,
#   't': 1612155600000,
#   'n': 924206},
#  {'v': 83259967.0,
#   'vw': 135.2222,
#   'o': 135.73,
#   'c': 134.99,
#   'h': 136.31,
#   'l': 134.61,
#   't': 1612242000000,
#   'n': 689676},
#  {'v': 85880937.0,
#   'vw': 134.6595,
#   'o': 135.76,
#   'c': 133.94,
#   'h': 135.77,
#   'l': 133.61,
#   't': 1612328400000,
#   'n': 699067},
#  {'v': 84141061.0,
#   'vw': 136.1869,
#   'o': 136.3,
#   'c': 137.39,
#   'h': 137.4,
#   'l': 134.59,
#   't': 1612414800000,
#   'n': 658076},
#  {'v': 75303830.0,
#   'vw': 136.6507,
#   'o': 137.35,
#   'c': 136.76,
#   'h': 137.42,
#   'l': 135.86,
#   't': 1612501200000,
#   'n': 616037},
#  {'v': 71297214.0,
#   'vw': 136.2094,
#   'o': 136.03,
#   'c': 136.91,
#   'h': 136.96,
#   'l': 134.92,
#   't': 1612760400000,
#   'n': 614469},
#  {'v': 76774213.0,
#   'vw': 136.7346,
#   'o': 136.62,
#   'c': 136.01,
#   'h': 137.877,
#   'l': 135.85,
#   't': 1612846800000,
#   'n': 536824},
#  {'v': 72546563.0,
#   'vw': 135.4825,
#   'o': 136.48,
#   'c': 135.39,
#   'h': 136.99,
#   'l': 134.4,
#   't': 1612933200000,
#   'n': 605205},
#  {'v': 64280029.0,
#   'vw': 134.8643,
#   'o': 135.9,
#   'c': 135.13,
#   'h': 136.39,
#   'l': 133.77,
#   't': 1613019600000,
#   'n': 547785},
#  {'v': 60136930.0,
#   'vw': 134.5208,
#   'o': 134.35,
#   'c': 135.37,
#   'h': 135.53,
#   'l': 133.6921,
#   't': 1613106000000,
#   'n': 481804},
#  {'v': 80576316.0,
#   'vw': 133.8643,
#   'o': 135.49,
#   'c': 133.19,
#   'h': 136.01,
#   'l': 132.79,
#   't': 1613451600000,
#   'n': 741080},
#  {'v': 97991849.0,
#   'vw': 130.5913,
#   'o': 131.25,
#   'c': 130.84,
#   'h': 132.22,
#   'l': 129.47,
#   't': 1613538000000,
#   'n': 971318},
#  {'v': 96156748.0,
#   'vw': 128.8633,
#   'o': 129.2,
#   'c': 129.71,
#   'h': 129.995,
#   'l': 127.41,
#   't': 1613624400000,
#   'n': 859568},
#  {'v': 87340834.0,
#   'vw': 129.766,
#   'o': 130.24,
#   'c': 129.87,
#   'h': 130.71,
#   'l': 128.8,
#   't': 1613710800000,
#   'n': 683754},
#  {'v': 103295419.0,
#   'vw': 127.0448,
#   'o': 128.01,
#   'c': 126,
#   'h': 129.72,
#   'l': 125.6,
#   't': 1613970000000,
#   'n': 969980},
#  {'v': 158252662.0,
#   'vw': 123.3074,
#   'o': 123.76,
#   'c': 125.86,
#   'h': 126.71,
#   'l': 118.39,
#   't': 1614056400000,
#   'n': 1547442},
#  {'v': 110789904.0,
#   'vw': 124.4278,
#   'o': 124.94,
#   'c': 125.35,
#   'h': 125.56,
#   'l': 122.23,
#   't': 1614142800000,
#   'n': 965716},
#  {'v': 148199540.0,
#   'vw': 122.6039,
#   'o': 124.68,
#   'c': 120.99,
#   'h': 126.4585,
#   'l': 120.54,
#   't': 1614229200000,
#   'n': 1365697},
#  {'v': 164559569.0,
#   'vw': 122.9199,
#   'o': 122.59,
#   'c': 121.26,
#   'h': 124.85,
#   'l': 121.2,
#   't': 1614315600000,
#   'n': 1289339},
#  {'v': 116307892.0,
#   'vw': 126.0528,
#   'o': 123.75,
#   'c': 127.79,
#   'h': 127.93,
#   'l': 122.79,
#   't': 1614574800000,
#   'n': 924487},
#  {'v': 102260945.0,
#   'vw': 126.1136,
#   'o': 128.41,
#   'c': 125.12,
#   'h': 128.72,
#   'l': 125.01,
#   't': 1614661200000,
#   'n': 831904},
#  {'v': 112966340.0,
#   'vw': 123.378,
#   'o': 124.81,
#   'c': 122.06,
#   'h': 125.71,
#   'l': 121.84,
#   't': 1614747600000,
#   'n': 992159},
#  {'v': 178049975.0,
#   'vw': 120.805,
#   'o': 121.75,
#   'c': 120.13,
#   'h': 123.6,
#   'l': 118.62,
#   't': 1614834000000,
#   'n': 1689127},
#  {'v': 153592201.0,
#   'vw': 119.7787,
#   'o': 120.98,
#   'c': 121.42,
#   'h': 121.935,
#   'l': 117.57,
#   't': 1614920400000,
#   'n': 1472273},
#  {'v': 154376610.0,
#   'vw': 117.9393,
#   'o': 120.93,
#   'c': 116.36,
#   'h': 121,
#   'l': 116.21,
#   't': 1615179600000,
#   'n': 1540729},
#  {'v': 129272780.0,
#   'vw': 120.6902,
#   'o': 119.03,
#   'c': 121.085,
#   'h': 122.06,
#   'l': 118.79,
#   't': 1615266000000,
#   'n': 1009102},
#  {'v': 111886327.0,
#   'vw': 120.3297,
#   'o': 121.69,
#   'c': 119.98,
#   'h': 122.17,
#   'l': 119.45,
#   't': 1615352400000,
#   'n': 1031831},
#  {'v': 102991014.0,
#   'vw': 122.0659,
#   'o': 122.54,
#   'c': 121.96,
#   'h': 123.21,
#   'l': 121.26,
#   't': 1615438800000,
#   'n': 790211},
#  {'v': 87955050.0,
#   'vw': 120.2455,
#   'o': 120.4,
#   'c': 121.03,
#   'h': 121.17,
#   'l': 119.16,
#   't': 1615525200000,
#   'n': 762384},
#  {'v': 92568955.0,
#   'vw': 122.9775,
#   'o': 121.41,
#   'c': 123.99,
#   'h': 124,
#   'l': 120.42,
#   't': 1615780800000,
#   'n': 711876},
#  {'v': 115226936.0,
#   'vw': 125.9513,
#   'o': 125.7,
#   'c': 125.57,
#   'h': 127.22,
#   'l': 124.715,
#   't': 1615867200000,
#   'n': 835613},
#  {'v': 111632636.0,
#   'vw': 123.7795,
#   'o': 124.05,
#   'c': 124.76,
#   'h': 125.8599,
#   'l': 122.336,
#   't': 1615953600000,
#   'n': 896781},
#  {'v': 121367255.0,
#   'vw': 121.6504,
#   'o': 122.88,
#   'c': 120.53,
#   'h': 123.18,
#   'l': 120.32,
#   't': 1616040000000,
#   'n': 970641},
#  {'v': 184668022.0,
#   'vw': 120.2005,
#   'o': 119.9,
#   'c': 119.99,
#   'h': 121.43,
#   'l': 119.675,
#   't': 1616126400000,
#   'n': 881988},
#  {'v': 111816184.0,
#   'vw': 122.8192,
#   'o': 120.33,
#   'c': 123.39,
#   'h': 123.87,
#   'l': 120.26,
#   't': 1616385600000,
#   'n': 723652},
#  {'v': 95051142.0,
#   'vw': 122.999,
#   'o': 123.33,
#   'c': 122.54,
#   'h': 124.24,
#   'l': 122.14,
#   't': 1616472000000,
#   'n': 641822},
#  {'v': 88525685.0,
#   'vw': 121.2133,
#   'o': 122.82,
#   'c': 120.09,
#   'h': 122.9,
#   'l': 120.065,
#   't': 1616558400000,
#   'n': 653239},
#  {'v': 98809281.0,
#   'vw': 120.244,
#   'o': 119.54,
#   'c': 120.59,
#   'h': 121.66,
#   'l': 119,
#   't': 1616644800000,
#   'n': 807588},
#  {'v': 94071234.0,
#   'vw': 120.2314,
#   'o': 120.35,
#   'c': 121.21,
#   'h': 121.48,
#   'l': 118.92,
#   't': 1616731200000,
#   'n': 716066},
#  {'v': 80819203.0,
#   'vw': 121.4709,
#   'o': 121.65,
#   'c': 121.39,
#   'h': 122.58,
#   'l': 120.7299,
#   't': 1616990400000,
#   'n': 584885},
#  {'v': 84507919.0,
#   'vw': 119.7036,
#   'o': 120.11,
#   'c': 119.9,
#   'h': 120.4031,
#   'l': 118.86,
#   't': 1617076800000,
#   'n': 667918},
#  {'v': 118323826.0,
#   'vw': 122.6039,
#   'o': 121.65,
#   'c': 122.15,
#   'h': 123.52,
#   'l': 121.15,
#   't': 1617163200000,
#   'n': 740850},
#  {'v': 75089134.0,
#   'vw': 123.1513,
#   'o': 123.66,
#   'c': 123,
#   'h': 124.18,
#   'l': 122.49,
#   't': 1617249600000,
#   'n': 526273},
#  {'v': 88251175.0,
#   'vw': 125.3311,
#   'o': 123.87,
#   'c': 125.9,
#   'h': 126.1601,
#   'l': 123.07,
#   't': 1617595200000,
#   'n': 642630},
#  {'v': 80171253.0,
#   'vw': 126.364,
#   'o': 126.5,
#   'c': 126.21,
#   'h': 127.13,
#   'l': 125.65,
#   't': 1617681600000,
#   'n': 564312},
#  {'v': 83256716.0,
#   'vw': 127.1011,
#   'o': 125.83,
#   'c': 127.9,
#   'h': 127.92,
#   'l': 125.14,
#   't': 1617768000000,
#   'n': 555603},
#  {'v': 88844591.0,
#   'vw': 129.7402,
#   'o': 128.95,
#   'c': 130.36,
#   'h': 130.39,
#   'l': 128.52,
#   't': 1617854400000,
#   'n': 639632},
#  {'v': 106615653.0,
#   'vw': 131.6977,
#   'o': 129.8,
#   'c': 132.995,
#   'h': 133.04,
#   'l': 129.47,
#   't': 1617940800000,
#   'n': 701349},
#  {'v': 91388983.0,
#   'vw': 131.5117,
#   'o': 132.52,
#   'c': 131.24,
#   'h': 132.85,
#   'l': 130.63,
#   't': 1618200000000,
#   'n': 612036},
#  {'v': 90761995.0,
#   'vw': 133.732,
#   'o': 132.44,
#   'c': 134.43,
#   'h': 134.66,
#   'l': 131.93,
#   't': 1618286400000,
#   'n': 640753},
#  {'v': 86222782.0,
#   'vw': 133.0216,
#   'o': 134.94,
#   'c': 132.03,
#   'h': 135,
#   'l': 131.655,
#   't': 1618372800000,
#   'n': 668827},
#  {'v': 89347102.0,
#   'vw': 134.3964,
#   'o': 133.82,
#   'c': 134.5,
#   'h': 135,
#   'l': 133.64,
#   't': 1618459200000,
#   'n': 608980},
#  {'v': 84360386.0,
#   'vw': 134.0367,
#   'o': 134.3,
#   'c': 134.16,
#   'h': 134.67,
#   'l': 133.28,
#   't': 1618545600000,
#   'n': 541233},
#  {'v': 94264215.0,
#   'vw': 134.5998,
#   'o': 133.51,
#   'c': 134.84,
#   'h': 135.47,
#   'l': 133.34,
#   't': 1618804800000,
#   'n': 625255},
#  {'v': 94812249.0,
#   'vw': 133.4438,
#   'o': 135.02,
#   'c': 133.11,
#   'h': 135.53,
#   'l': 131.81,
#   't': 1618891200000,
#   'n': 744673},
#  {'v': 68826135.0,
#   'vw': 132.8647,
#   'o': 132.36,
#   'c': 133.5,
#   'h': 133.75,
#   'l': 131.3001,
#   't': 1618977600000,
#   'n': 508230},
#  {'v': 84566456.0,
#   'vw': 132.7723,
#   'o': 133.04,
#   'c': 131.94,
#   'h': 134.15,
#   'l': 131.41,
#   't': 1619064000000,
#   'n': 615670},
#  {'v': 78666779.0,
#   'vw': 134.1622,
#   'o': 132.16,
#   'c': 134.32,
#   'h': 135.12,
#   'l': 132.16,
#   't': 1619150400000,
#   'n': 519533},
#  {'v': 66888509.0,
#   'vw': 134.5418,
#   'o': 134.83,
#   'c': 134.72,
#   'h': 135.06,
#   'l': 133.56,
#   't': 1619409600000,
#   'n': 484069},
#  {'v': 66015804.0,
#   'vw': 134.5907,
#   'o': 135.01,
#   'c': 134.39,
#   'h': 135.41,
#   'l': 134.11,
#   't': 1619496000000,
#   'n': 480003},
#  {'v': 107746597.0,
#   'vw': 134.6526,
#   'o': 134.31,
#   'c': 133.58,
#   'h': 135.02,
#   'l': 133.08,
#   't': 1619582400000,
#   'n': 783355},
#  {'v': 151100953.0,
#   'vw': 134.1771,
#   'o': 136.47,
#   'c': 133.48,
#   'h': 137.07,
#   'l': 132.45,
#   't': 1619668800000,
#   'n': 1059387},
#  {'v': 109425466.0,
#   'vw': 132.194,
#   'o': 131.78,
#   'c': 131.46,
#   'h': 133.56,
#   'l': 131.065,
#   't': 1619755200000,
#   'n': 701292},
#  {'v': 75135100.0,
#   'vw': 132.8122,
#   'o': 132.04,
#   'c': 132.54,
#   'h': 134.07,
#   'l': 131.83,
#   't': 1620014400000,
#   'n': 580631},
#  {'v': 137544918.0,
#   'vw': 127.9654,
#   'o': 131.19,
#   'c': 127.85,
#   'h': 131.4899,
#   'l': 126.7,
#   't': 1620100800000,
#   'n': 1182700},
#  {'v': 84000900.0,
#   'vw': 129.2267,
#   'o': 129.2,
#   'c': 128.1,
#   'h': 130.45,
#   'l': 127.97,
#   't': 1620187200000,
#   'n': 659279},
#  {'v': 78064334.0,
#   'vw': 128.6316,
#   'o': 127.89,
#   'c': 129.74,
#   'h': 129.75,
#   'l': 127.13,
#   't': 1620273600000,
#   'n': 607088},
#  {'v': 77691273.0,
#   'vw': 130.4433,
#   'o': 130.85,
#   'c': 130.21,
#   'h': 131.2582,
#   'l': 129.475,
#   't': 1620360000000,
#   'n': 545296},
#  {'v': 88071229.0,
#   'vw': 127.8422,
#   'o': 129.41,
#   'c': 126.85,
#   'h': 129.54,
#   'l': 126.81,
#   't': 1620619200000,
#   'n': 680681},
#  {'v': 126142826.0,
#   'vw': 124.7406,
#   'o': 123.5,
#   'c': 125.91,
#   'h': 126.27,
#   'l': 122.77,
#   't': 1620705600000,
#   'n': 922237},
#  {'v': 112172282.0,
#   'vw': 123.0599,
#   'o': 123.4,
#   'c': 122.77,
#   'h': 124.64,
#   'l': 122.25,
#   't': 1620792000000,
#   'n': 876763},
#  {'v': 105850339.0,
#   'vw': 125.1884,
#   'o': 124.58,
#   'c': 124.97,
#   'h': 126.15,
#   'l': 124.26,
#   't': 1620878400000,
#   'n': 788603},
#  {'v': 81872951.0,
#   'vw': 126.9616,
#   'o': 126.25,
#   'c': 127.45,
#   'h': 127.89,
#   'l': 125.85,
#   't': 1620964800000,
#   'n': 535527},
#  {'v': 74216624.0,
#   'vw': 125.9467,
#   'o': 126.82,
#   'c': 126.27,
#   'h': 126.93,
#   'l': 125.17,
#   't': 1621224000000,
#   'n': 502288},
#  {'v': 63342929.0,
#   'vw': 125.9763,
#   'o': 126.56,
#   'c': 124.85,
#   'h': 126.99,
#   'l': 124.78,
#   't': 1621310400000,
#   'n': 493538},
#  {'v': 92593489.0,
#   'vw': 124.0238,
#   'o': 123.16,
#   'c': 124.69,
#   'h': 124.915,
#   'l': 122.86,
#   't': 1621396800000,
#   'n': 674397},
#  {'v': 76852123.0,
#   'vw': 126.8581,
#   'o': 125.23,
#   'c': 127.31,
#   'h': 127.72,
#   'l': 125.1,
#   't': 1621483200000,
#   'n': 494796},
#  {'v': 79295436.0,
#   'vw': 126.1486,
#   'o': 127.82,
#   'c': 125.43,
#   'h': 128,
#   'l': 125.21,
#   't': 1621569600000,
#   'n': 527860},
#  {'v': 63067944.0,
#   'vw': 127.2698,
#   'o': 126.01,
#   'c': 127.1,
#   'h': 127.94,
#   'l': 125.94,
#   't': 1621828800000,
#   'n': 442120},
#  {'v': 72009482.0,
#   'vw': 127.0739,
#   'o': 127.82,
#   'c': 126.9,
#   'h': 128.32,
#   'l': 126.32,
#   't': 1621915200000,
#   'n': 462909},
#  {'v': 56443920.0,
#   'vw': 126.8655,
#   'o': 126.955,
#   'c': 126.85,
#   'h': 127.39,
#   'l': 126.42,
#   't': 1622001600000,
#   'n': 415320},
#  {'v': 94625601.0,
#   'vw': 126.1253,
#   'o': 126.44,
#   'c': 125.28,
#   'h': 127.64,
#   'l': 125.08,
#   't': 1622088000000,
#   'n': 545582},
#  {'v': 71238509.0,
#   'vw': 125.0642,
#   'o': 125.57,
#   'c': 124.61,
#   'h': 125.8,
#   'l': 124.55,
#   't': 1622174400000,
#   'n': 527853},
#  {'v': 65562118.0,
#   'vw': 124.5894,
#   'o': 125.08,
#   'c': 124.28,
#   'h': 125.35,
#   'l': 123.94,
#   't': 1622520000000,
#   'n': 501106},
#  {'v': 58674262.0,
#   'vw': 124.769,
#   'o': 124.28,
#   'c': 125.06,
#   'h': 125.24,
#   'l': 124.05,
#   't': 1622606400000,
#   'n': 461408},
#  {'v': 75699170.0,
#   'vw': 123.7708,
#   'o': 124.68,
#   'c': 123.54,
#   'h': 124.85,
#   'l': 123.13,
#   't': 1622692800000,
#   'n': 562249},
#  {'v': 75169343.0,
#   'vw': 125.368,
#   'o': 124.07,
#   'c': 125.89,
#   'h': 126.16,
#   'l': 123.85,
#   't': 1622779200000,
#   'n': 467760},
#  {'v': 71057550.0,
#   'vw': 125.3691,
#   'o': 126.17,
#   'c': 125.9,
#   'h': 126.32,
#   'l': 124.8321,
#   't': 1623038400000,
#   'n': 504254},
#  {'v': 74403774.0,
#   'vw': 127.0742,
#   'o': 126.6,
#   'c': 126.74,
#   'h': 128.46,
#   'l': 126.2101,
#   't': 1623124800000,
#   'n': 532078},
#  {'v': 56695219.0,
#   'vw': 127.0733,
#   'o': 127.21,
#   'c': 127.13,
#   'h': 127.75,
#   'l': 126.52,
#   't': 1623211200000,
#   'n': 382625},
#  {'v': 71186421.0,
#   'vw': 126.6607,
#   'o': 127.02,
#   'c': 126.11,
#   'h': 128.19,
#   'l': 125.94,
#   't': 1623297600000,
#   'n': 498371},
#  {'v': 53522373.0,
#   'vw': 127.0246,
#   'o': 126.53,
#   'c': 127.35,
#   'h': 127.44,
#   'l': 126.1,
#   't': 1623384000000,
#   'n': 354080},
#  {'v': 96906490.0,
#   'vw': 129.6322,
#   'o': 127.82,
#   'c': 130.48,
#   'h': 130.54,
#   'l': 127.07,
#   't': 1623643200000,
#   'n': 563595},
#  {'v': 62725532.0,
#   'vw': 129.8358,
#   'o': 129.94,
#   'c': 129.64,
#   'h': 130.6,
#   'l': 129.39,
#   't': 1623729600000,
#   'n': 416230},
#  {'v': 91793025.0,
#   'vw': 130.0001,
#   'o': 130.37,
#   'c': 130.15,
#   'h': 130.89,
#   'l': 128.461,
#   't': 1623816000000,
#   'n': 619028},
#  {'v': 96721669.0,
#   'vw': 131.5645,
#   'o': 129.8,
#   'c': 131.79,
#   'h': 132.55,
#   'l': 129.65,
#   't': 1623902400000,
#   'n': 652025},
#  {'v': 108890309.0,
#   'vw': 130.7868,
#   'o': 130.71,
#   'c': 130.46,
#   'h': 131.51,
#   'l': 130.24,
#   't': 1623988800000,
#   'n': 557039},
#  {'v': 79269216.0,
#   'vw': 131.4999,
#   'o': 130.3,
#   'c': 132.3,
#   'h': 132.41,
#   'l': 129.21,
#   't': 1624248000000,
#   'n': 506660},
#  {'v': 73713618.0,
#   'vw': 133.0905,
#   'o': 132.13,
#   'c': 133.98,
#   'h': 134.08,
#   'l': 131.62,
#   't': 1624334400000,
#   'n': 481082},
#  {'v': 60214200.0,
#   'vw': 133.7872,
#   'o': 133.77,
#   'c': 133.7,
#   'h': 134.32,
#   'l': 133.23,
#   't': 1624420800000,
#   'n': 424752},
#  {'v': 68710998.0,
#   'vw': 133.7663,
#   'o': 134.45,
#   'c': 133.41,
#   'h': 134.64,
#   'l': 132.93,
#   't': 1624507200000,
#   'n': 443492}]

# %%
text['results'][0]['v']
# Out:
# 143285672.0

# %%
# Watch the double quotes inside the fstring.

for x in text['results'][0]:
    print(f'{x}: {text["results"][0][x]}')
# Out:
# v: 143285672.0
# vw: 129.7326
# o: 133.52
# c: 129.41
# h: 133.6116
# l: 126.76
# t: 1609736400000
# n: 1310217

# %%
import pandas as pd
df = pd.read_json(url)

# %%
df.head()
# Out:
#   ticker  queryCount  resultsCount  adjusted  \
# 0   AAPL         120           120      True
# 1   AAPL         120           120      True
# 2   AAPL         120           120      True
# 3   AAPL         120           120      True
# 4   AAPL         120           120      True
#
#                                              results status  \
# 0  {'v': 143285672.0, 'vw': 129.7326, 'o': 133.52...     OK
# 1  {'v': 97664898.0, 'vw': 130.7179, 'o': 128.89,...     OK
# 2  {'v': 155087970.0, 'vw': 128.3502, 'o': 127.72...     OK
# 3  {'v': 109578157.0, 'vw': 130.1539, 'o': 128.36...     OK
# 4  {'v': 105158245.0, 'vw': 131.5657, 'o': 132.43...     OK
#
#                          request_id  count
# 0  6c235020890f3ed81807b5b60c1f26f4    120
# 1  6c235020890f3ed81807b5b60c1f26f4    120
# 2  6c235020890f3ed81807b5b60c1f26f4    120
# 3  6c235020890f3ed81807b5b60c1f26f4    120
# 4  6c235020890f3ed81807b5b60c1f26f4    120

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ticker        120 non-null    object
#  1   queryCount    120 non-null    int64
#  2   resultsCount  120 non-null    int64
#  3   adjusted      120 non-null    bool
#  4   results       120 non-null    object
#  5   status        120 non-null    object
#  6   request_id    120 non-null    object
#  7   count         120 non-null    int64
# dtypes: bool(1), int64(3), object(4)
# memory usage: 6.8+ KB

# %%
first_result = text["results"][0]

# %%
first_result
# Out:
# {'v': 143285672.0,
#  'vw': 129.7326,
#  'o': 133.52,
#  'c': 129.41,
#  'h': 133.6116,
#  'l': 126.76,
#  't': 1609736400000,
#  'n': 1310217}

# %%
results = text["results"]

# %%
results
# Out:
# [{'v': 143285672.0,
#   'vw': 129.7326,
#   'o': 133.52,
#   'c': 129.41,
#   'h': 133.6116,
#   'l': 126.76,
#   't': 1609736400000,
#   'n': 1310217},
#  {'v': 97664898.0,
#   'vw': 130.7179,
#   'o': 128.89,
#   'c': 131.01,
#   'h': 131.74,
#   'l': 128.43,
#   't': 1609822800000,
#   'n': 707577},
#  {'v': 155087970.0,
#   'vw': 128.3502,
#   'o': 127.72,
#   'c': 126.6,
#   'h': 131.0499,
#   'l': 126.382,
#   't': 1609909200000,
#   'n': 1202574},
#  {'v': 109578157.0,
#   'vw': 130.1539,
#   'o': 128.36,
#   'c': 130.92,
#   'h': 131.63,
#   'l': 127.86,
#   't': 1609995600000,
#   'n': 718357},
#  {'v': 105158245.0,
#   'vw': 131.5657,
#   'o': 132.43,
#   'c': 132.05,
#   'h': 132.63,
#   'l': 130.23,
#   't': 1610082000000,
#   'n': 800069},
#  {'v': 100617160.0,
#   'vw': 129.3232,
#   'o': 129.19,
#   'c': 128.98,
#   'h': 130.17,
#   'l': 128.5,
#   't': 1610341200000,
#   'n': 775027},
#  {'v': 91851145.0,
#   'vw': 128.4834,
#   'o': 128.5,
#   'c': 128.8,
#   'h': 129.69,
#   'l': 126.86,
#   't': 1610427600000,
#   'n': 692719},
#  {'v': 88636831.0,
#   'vw': 130.5588,
#   'o': 128.76,
#   'c': 130.89,
#   'h': 131.45,
#   'l': 128.49,
#   't': 1610514000000,
#   'n': 596230},
#  {'v': 89671755.0,
#   'vw': 129.7381,
#   'o': 130.8,
#   'c': 128.91,
#   'h': 131,
#   'l': 128.76,
#   't': 1610600400000,
#   'n': 651392},
#  {'v': 111196831.0,
#   'vw': 128.264,
#   'o': 128.78,
#   'c': 127.14,
#   'h': 130.2242,
#   'l': 127,
#   't': 1610686800000,
#   'n': 713312},
#  {'v': 90750329.0,
#   'vw': 127.6974,
#   'o': 127.78,
#   'c': 127.83,
#   'h': 128.71,
#   'l': 126.938,
#   't': 1611032400000,
#   'n': 599768},
#  {'v': 104134039.0,
#   'vw': 131.4664,
#   'o': 128.66,
#   'c': 132.03,
#   'h': 132.49,
#   'l': 128.55,
#   't': 1611118800000,
#   'n': 668571},
#  {'v': 120256319.0,
#   'vw': 135.8584,
#   'o': 133.8,
#   'c': 136.87,
#   'h': 139.67,
#   'l': 133.59,
#   't': 1611205200000,
#   'n': 834998},
#  {'v': 114234010.0,
#   'vw': 137.8544,
#   'o': 136.28,
#   'c': 139.07,
#   'h': 139.85,
#   'l': 135.02,
#   't': 1611291600000,
#   'n': 744041},
#  {'v': 157588183.0,
#   'vw': 142.6255,
#   'o': 143.07,
#   'c': 142.92,
#   'h': 145.09,
#   'l': 136.54,
#   't': 1611550800000,
#   'n': 1226813},
#  {'v': 98390205.0,
#   'vw': 142.8442,
#   'o': 143.6,
#   'c': 143.16,
#   'h': 144.3,
#   'l': 141.37,
#   't': 1611637200000,
#   'n': 743285},
#  {'v': 140613944.0,
#   'vw': 142.3522,
#   'o': 143.43,
#   'c': 142.06,
#   'h': 144.3,
#   'l': 140.41,
#   't': 1611723600000,
#   'n': 1155710},
#  {'v': 142508399.0,
#   'vw': 139.1841,
#   'o': 139.52,
#   'c': 137.09,
#   'h': 141.99,
#   'l': 136.7,
#   't': 1611810000000,
#   'n': 1239461},
#  {'v': 177506312.0,
#   'vw': 132.7372,
#   'o': 135.83,
#   'c': 131.96,
#   'h': 136.74,
#   'l': 130.21,
#   't': 1611896400000,
#   'n': 1695154},
#  {'v': 106239823.0,
#   'vw': 133.7923,
#   'o': 133.75,
#   'c': 134.14,
#   'h': 135.38,
#   'l': 130.93,
#   't': 1612155600000,
#   'n': 924206},
#  {'v': 83259967.0,
#   'vw': 135.2222,
#   'o': 135.73,
#   'c': 134.99,
#   'h': 136.31,
#   'l': 134.61,
#   't': 1612242000000,
#   'n': 689676},
#  {'v': 85880937.0,
#   'vw': 134.6595,
#   'o': 135.76,
#   'c': 133.94,
#   'h': 135.77,
#   'l': 133.61,
#   't': 1612328400000,
#   'n': 699067},
#  {'v': 84141061.0,
#   'vw': 136.1869,
#   'o': 136.3,
#   'c': 137.39,
#   'h': 137.4,
#   'l': 134.59,
#   't': 1612414800000,
#   'n': 658076},
#  {'v': 75303830.0,
#   'vw': 136.6507,
#   'o': 137.35,
#   'c': 136.76,
#   'h': 137.42,
#   'l': 135.86,
#   't': 1612501200000,
#   'n': 616037},
#  {'v': 71297214.0,
#   'vw': 136.2094,
#   'o': 136.03,
#   'c': 136.91,
#   'h': 136.96,
#   'l': 134.92,
#   't': 1612760400000,
#   'n': 614469},
#  {'v': 76774213.0,
#   'vw': 136.7346,
#   'o': 136.62,
#   'c': 136.01,
#   'h': 137.877,
#   'l': 135.85,
#   't': 1612846800000,
#   'n': 536824},
#  {'v': 72546563.0,
#   'vw': 135.4825,
#   'o': 136.48,
#   'c': 135.39,
#   'h': 136.99,
#   'l': 134.4,
#   't': 1612933200000,
#   'n': 605205},
#  {'v': 64280029.0,
#   'vw': 134.8643,
#   'o': 135.9,
#   'c': 135.13,
#   'h': 136.39,
#   'l': 133.77,
#   't': 1613019600000,
#   'n': 547785},
#  {'v': 60136930.0,
#   'vw': 134.5208,
#   'o': 134.35,
#   'c': 135.37,
#   'h': 135.53,
#   'l': 133.6921,
#   't': 1613106000000,
#   'n': 481804},
#  {'v': 80576316.0,
#   'vw': 133.8643,
#   'o': 135.49,
#   'c': 133.19,
#   'h': 136.01,
#   'l': 132.79,
#   't': 1613451600000,
#   'n': 741080},
#  {'v': 97991849.0,
#   'vw': 130.5913,
#   'o': 131.25,
#   'c': 130.84,
#   'h': 132.22,
#   'l': 129.47,
#   't': 1613538000000,
#   'n': 971318},
#  {'v': 96156748.0,
#   'vw': 128.8633,
#   'o': 129.2,
#   'c': 129.71,
#   'h': 129.995,
#   'l': 127.41,
#   't': 1613624400000,
#   'n': 859568},
#  {'v': 87340834.0,
#   'vw': 129.766,
#   'o': 130.24,
#   'c': 129.87,
#   'h': 130.71,
#   'l': 128.8,
#   't': 1613710800000,
#   'n': 683754},
#  {'v': 103295419.0,
#   'vw': 127.0448,
#   'o': 128.01,
#   'c': 126,
#   'h': 129.72,
#   'l': 125.6,
#   't': 1613970000000,
#   'n': 969980},
#  {'v': 158252662.0,
#   'vw': 123.3074,
#   'o': 123.76,
#   'c': 125.86,
#   'h': 126.71,
#   'l': 118.39,
#   't': 1614056400000,
#   'n': 1547442},
#  {'v': 110789904.0,
#   'vw': 124.4278,
#   'o': 124.94,
#   'c': 125.35,
#   'h': 125.56,
#   'l': 122.23,
#   't': 1614142800000,
#   'n': 965716},
#  {'v': 148199540.0,
#   'vw': 122.6039,
#   'o': 124.68,
#   'c': 120.99,
#   'h': 126.4585,
#   'l': 120.54,
#   't': 1614229200000,
#   'n': 1365697},
#  {'v': 164559569.0,
#   'vw': 122.9199,
#   'o': 122.59,
#   'c': 121.26,
#   'h': 124.85,
#   'l': 121.2,
#   't': 1614315600000,
#   'n': 1289339},
#  {'v': 116307892.0,
#   'vw': 126.0528,
#   'o': 123.75,
#   'c': 127.79,
#   'h': 127.93,
#   'l': 122.79,
#   't': 1614574800000,
#   'n': 924487},
#  {'v': 102260945.0,
#   'vw': 126.1136,
#   'o': 128.41,
#   'c': 125.12,
#   'h': 128.72,
#   'l': 125.01,
#   't': 1614661200000,
#   'n': 831904},
#  {'v': 112966340.0,
#   'vw': 123.378,
#   'o': 124.81,
#   'c': 122.06,
#   'h': 125.71,
#   'l': 121.84,
#   't': 1614747600000,
#   'n': 992159},
#  {'v': 178049975.0,
#   'vw': 120.805,
#   'o': 121.75,
#   'c': 120.13,
#   'h': 123.6,
#   'l': 118.62,
#   't': 1614834000000,
#   'n': 1689127},
#  {'v': 153592201.0,
#   'vw': 119.7787,
#   'o': 120.98,
#   'c': 121.42,
#   'h': 121.935,
#   'l': 117.57,
#   't': 1614920400000,
#   'n': 1472273},
#  {'v': 154376610.0,
#   'vw': 117.9393,
#   'o': 120.93,
#   'c': 116.36,
#   'h': 121,
#   'l': 116.21,
#   't': 1615179600000,
#   'n': 1540729},
#  {'v': 129272780.0,
#   'vw': 120.6902,
#   'o': 119.03,
#   'c': 121.085,
#   'h': 122.06,
#   'l': 118.79,
#   't': 1615266000000,
#   'n': 1009102},
#  {'v': 111886327.0,
#   'vw': 120.3297,
#   'o': 121.69,
#   'c': 119.98,
#   'h': 122.17,
#   'l': 119.45,
#   't': 1615352400000,
#   'n': 1031831},
#  {'v': 102991014.0,
#   'vw': 122.0659,
#   'o': 122.54,
#   'c': 121.96,
#   'h': 123.21,
#   'l': 121.26,
#   't': 1615438800000,
#   'n': 790211},
#  {'v': 87955050.0,
#   'vw': 120.2455,
#   'o': 120.4,
#   'c': 121.03,
#   'h': 121.17,
#   'l': 119.16,
#   't': 1615525200000,
#   'n': 762384},
#  {'v': 92568955.0,
#   'vw': 122.9775,
#   'o': 121.41,
#   'c': 123.99,
#   'h': 124,
#   'l': 120.42,
#   't': 1615780800000,
#   'n': 711876},
#  {'v': 115226936.0,
#   'vw': 125.9513,
#   'o': 125.7,
#   'c': 125.57,
#   'h': 127.22,
#   'l': 124.715,
#   't': 1615867200000,
#   'n': 835613},
#  {'v': 111632636.0,
#   'vw': 123.7795,
#   'o': 124.05,
#   'c': 124.76,
#   'h': 125.8599,
#   'l': 122.336,
#   't': 1615953600000,
#   'n': 896781},
#  {'v': 121367255.0,
#   'vw': 121.6504,
#   'o': 122.88,
#   'c': 120.53,
#   'h': 123.18,
#   'l': 120.32,
#   't': 1616040000000,
#   'n': 970641},
#  {'v': 184668022.0,
#   'vw': 120.2005,
#   'o': 119.9,
#   'c': 119.99,
#   'h': 121.43,
#   'l': 119.675,
#   't': 1616126400000,
#   'n': 881988},
#  {'v': 111816184.0,
#   'vw': 122.8192,
#   'o': 120.33,
#   'c': 123.39,
#   'h': 123.87,
#   'l': 120.26,
#   't': 1616385600000,
#   'n': 723652},
#  {'v': 95051142.0,
#   'vw': 122.999,
#   'o': 123.33,
#   'c': 122.54,
#   'h': 124.24,
#   'l': 122.14,
#   't': 1616472000000,
#   'n': 641822},
#  {'v': 88525685.0,
#   'vw': 121.2133,
#   'o': 122.82,
#   'c': 120.09,
#   'h': 122.9,
#   'l': 120.065,
#   't': 1616558400000,
#   'n': 653239},
#  {'v': 98809281.0,
#   'vw': 120.244,
#   'o': 119.54,
#   'c': 120.59,
#   'h': 121.66,
#   'l': 119,
#   't': 1616644800000,
#   'n': 807588},
#  {'v': 94071234.0,
#   'vw': 120.2314,
#   'o': 120.35,
#   'c': 121.21,
#   'h': 121.48,
#   'l': 118.92,
#   't': 1616731200000,
#   'n': 716066},
#  {'v': 80819203.0,
#   'vw': 121.4709,
#   'o': 121.65,
#   'c': 121.39,
#   'h': 122.58,
#   'l': 120.7299,
#   't': 1616990400000,
#   'n': 584885},
#  {'v': 84507919.0,
#   'vw': 119.7036,
#   'o': 120.11,
#   'c': 119.9,
#   'h': 120.4031,
#   'l': 118.86,
#   't': 1617076800000,
#   'n': 667918},
#  {'v': 118323826.0,
#   'vw': 122.6039,
#   'o': 121.65,
#   'c': 122.15,
#   'h': 123.52,
#   'l': 121.15,
#   't': 1617163200000,
#   'n': 740850},
#  {'v': 75089134.0,
#   'vw': 123.1513,
#   'o': 123.66,
#   'c': 123,
#   'h': 124.18,
#   'l': 122.49,
#   't': 1617249600000,
#   'n': 526273},
#  {'v': 88251175.0,
#   'vw': 125.3311,
#   'o': 123.87,
#   'c': 125.9,
#   'h': 126.1601,
#   'l': 123.07,
#   't': 1617595200000,
#   'n': 642630},
#  {'v': 80171253.0,
#   'vw': 126.364,
#   'o': 126.5,
#   'c': 126.21,
#   'h': 127.13,
#   'l': 125.65,
#   't': 1617681600000,
#   'n': 564312},
#  {'v': 83256716.0,
#   'vw': 127.1011,
#   'o': 125.83,
#   'c': 127.9,
#   'h': 127.92,
#   'l': 125.14,
#   't': 1617768000000,
#   'n': 555603},
#  {'v': 88844591.0,
#   'vw': 129.7402,
#   'o': 128.95,
#   'c': 130.36,
#   'h': 130.39,
#   'l': 128.52,
#   't': 1617854400000,
#   'n': 639632},
#  {'v': 106615653.0,
#   'vw': 131.6977,
#   'o': 129.8,
#   'c': 132.995,
#   'h': 133.04,
#   'l': 129.47,
#   't': 1617940800000,
#   'n': 701349},
#  {'v': 91388983.0,
#   'vw': 131.5117,
#   'o': 132.52,
#   'c': 131.24,
#   'h': 132.85,
#   'l': 130.63,
#   't': 1618200000000,
#   'n': 612036},
#  {'v': 90761995.0,
#   'vw': 133.732,
#   'o': 132.44,
#   'c': 134.43,
#   'h': 134.66,
#   'l': 131.93,
#   't': 1618286400000,
#   'n': 640753},
#  {'v': 86222782.0,
#   'vw': 133.0216,
#   'o': 134.94,
#   'c': 132.03,
#   'h': 135,
#   'l': 131.655,
#   't': 1618372800000,
#   'n': 668827},
#  {'v': 89347102.0,
#   'vw': 134.3964,
#   'o': 133.82,
#   'c': 134.5,
#   'h': 135,
#   'l': 133.64,
#   't': 1618459200000,
#   'n': 608980},
#  {'v': 84360386.0,
#   'vw': 134.0367,
#   'o': 134.3,
#   'c': 134.16,
#   'h': 134.67,
#   'l': 133.28,
#   't': 1618545600000,
#   'n': 541233},
#  {'v': 94264215.0,
#   'vw': 134.5998,
#   'o': 133.51,
#   'c': 134.84,
#   'h': 135.47,
#   'l': 133.34,
#   't': 1618804800000,
#   'n': 625255},
#  {'v': 94812249.0,
#   'vw': 133.4438,
#   'o': 135.02,
#   'c': 133.11,
#   'h': 135.53,
#   'l': 131.81,
#   't': 1618891200000,
#   'n': 744673},
#  {'v': 68826135.0,
#   'vw': 132.8647,
#   'o': 132.36,
#   'c': 133.5,
#   'h': 133.75,
#   'l': 131.3001,
#   't': 1618977600000,
#   'n': 508230},
#  {'v': 84566456.0,
#   'vw': 132.7723,
#   'o': 133.04,
#   'c': 131.94,
#   'h': 134.15,
#   'l': 131.41,
#   't': 1619064000000,
#   'n': 615670},
#  {'v': 78666779.0,
#   'vw': 134.1622,
#   'o': 132.16,
#   'c': 134.32,
#   'h': 135.12,
#   'l': 132.16,
#   't': 1619150400000,
#   'n': 519533},
#  {'v': 66888509.0,
#   'vw': 134.5418,
#   'o': 134.83,
#   'c': 134.72,
#   'h': 135.06,
#   'l': 133.56,
#   't': 1619409600000,
#   'n': 484069},
#  {'v': 66015804.0,
#   'vw': 134.5907,
#   'o': 135.01,
#   'c': 134.39,
#   'h': 135.41,
#   'l': 134.11,
#   't': 1619496000000,
#   'n': 480003},
#  {'v': 107746597.0,
#   'vw': 134.6526,
#   'o': 134.31,
#   'c': 133.58,
#   'h': 135.02,
#   'l': 133.08,
#   't': 1619582400000,
#   'n': 783355},
#  {'v': 151100953.0,
#   'vw': 134.1771,
#   'o': 136.47,
#   'c': 133.48,
#   'h': 137.07,
#   'l': 132.45,
#   't': 1619668800000,
#   'n': 1059387},
#  {'v': 109425466.0,
#   'vw': 132.194,
#   'o': 131.78,
#   'c': 131.46,
#   'h': 133.56,
#   'l': 131.065,
#   't': 1619755200000,
#   'n': 701292},
#  {'v': 75135100.0,
#   'vw': 132.8122,
#   'o': 132.04,
#   'c': 132.54,
#   'h': 134.07,
#   'l': 131.83,
#   't': 1620014400000,
#   'n': 580631},
#  {'v': 137544918.0,
#   'vw': 127.9654,
#   'o': 131.19,
#   'c': 127.85,
#   'h': 131.4899,
#   'l': 126.7,
#   't': 1620100800000,
#   'n': 1182700},
#  {'v': 84000900.0,
#   'vw': 129.2267,
#   'o': 129.2,
#   'c': 128.1,
#   'h': 130.45,
#   'l': 127.97,
#   't': 1620187200000,
#   'n': 659279},
#  {'v': 78064334.0,
#   'vw': 128.6316,
#   'o': 127.89,
#   'c': 129.74,
#   'h': 129.75,
#   'l': 127.13,
#   't': 1620273600000,
#   'n': 607088},
#  {'v': 77691273.0,
#   'vw': 130.4433,
#   'o': 130.85,
#   'c': 130.21,
#   'h': 131.2582,
#   'l': 129.475,
#   't': 1620360000000,
#   'n': 545296},
#  {'v': 88071229.0,
#   'vw': 127.8422,
#   'o': 129.41,
#   'c': 126.85,
#   'h': 129.54,
#   'l': 126.81,
#   't': 1620619200000,
#   'n': 680681},
#  {'v': 126142826.0,
#   'vw': 124.7406,
#   'o': 123.5,
#   'c': 125.91,
#   'h': 126.27,
#   'l': 122.77,
#   't': 1620705600000,
#   'n': 922237},
#  {'v': 112172282.0,
#   'vw': 123.0599,
#   'o': 123.4,
#   'c': 122.77,
#   'h': 124.64,
#   'l': 122.25,
#   't': 1620792000000,
#   'n': 876763},
#  {'v': 105850339.0,
#   'vw': 125.1884,
#   'o': 124.58,
#   'c': 124.97,
#   'h': 126.15,
#   'l': 124.26,
#   't': 1620878400000,
#   'n': 788603},
#  {'v': 81872951.0,
#   'vw': 126.9616,
#   'o': 126.25,
#   'c': 127.45,
#   'h': 127.89,
#   'l': 125.85,
#   't': 1620964800000,
#   'n': 535527},
#  {'v': 74216624.0,
#   'vw': 125.9467,
#   'o': 126.82,
#   'c': 126.27,
#   'h': 126.93,
#   'l': 125.17,
#   't': 1621224000000,
#   'n': 502288},
#  {'v': 63342929.0,
#   'vw': 125.9763,
#   'o': 126.56,
#   'c': 124.85,
#   'h': 126.99,
#   'l': 124.78,
#   't': 1621310400000,
#   'n': 493538},
#  {'v': 92593489.0,
#   'vw': 124.0238,
#   'o': 123.16,
#   'c': 124.69,
#   'h': 124.915,
#   'l': 122.86,
#   't': 1621396800000,
#   'n': 674397},
#  {'v': 76852123.0,
#   'vw': 126.8581,
#   'o': 125.23,
#   'c': 127.31,
#   'h': 127.72,
#   'l': 125.1,
#   't': 1621483200000,
#   'n': 494796},
#  {'v': 79295436.0,
#   'vw': 126.1486,
#   'o': 127.82,
#   'c': 125.43,
#   'h': 128,
#   'l': 125.21,
#   't': 1621569600000,
#   'n': 527860},
#  {'v': 63067944.0,
#   'vw': 127.2698,
#   'o': 126.01,
#   'c': 127.1,
#   'h': 127.94,
#   'l': 125.94,
#   't': 1621828800000,
#   'n': 442120},
#  {'v': 72009482.0,
#   'vw': 127.0739,
#   'o': 127.82,
#   'c': 126.9,
#   'h': 128.32,
#   'l': 126.32,
#   't': 1621915200000,
#   'n': 462909},
#  {'v': 56443920.0,
#   'vw': 126.8655,
#   'o': 126.955,
#   'c': 126.85,
#   'h': 127.39,
#   'l': 126.42,
#   't': 1622001600000,
#   'n': 415320},
#  {'v': 94625601.0,
#   'vw': 126.1253,
#   'o': 126.44,
#   'c': 125.28,
#   'h': 127.64,
#   'l': 125.08,
#   't': 1622088000000,
#   'n': 545582},
#  {'v': 71238509.0,
#   'vw': 125.0642,
#   'o': 125.57,
#   'c': 124.61,
#   'h': 125.8,
#   'l': 124.55,
#   't': 1622174400000,
#   'n': 527853},
#  {'v': 65562118.0,
#   'vw': 124.5894,
#   'o': 125.08,
#   'c': 124.28,
#   'h': 125.35,
#   'l': 123.94,
#   't': 1622520000000,
#   'n': 501106},
#  {'v': 58674262.0,
#   'vw': 124.769,
#   'o': 124.28,
#   'c': 125.06,
#   'h': 125.24,
#   'l': 124.05,
#   't': 1622606400000,
#   'n': 461408},
#  {'v': 75699170.0,
#   'vw': 123.7708,
#   'o': 124.68,
#   'c': 123.54,
#   'h': 124.85,
#   'l': 123.13,
#   't': 1622692800000,
#   'n': 562249},
#  {'v': 75169343.0,
#   'vw': 125.368,
#   'o': 124.07,
#   'c': 125.89,
#   'h': 126.16,
#   'l': 123.85,
#   't': 1622779200000,
#   'n': 467760},
#  {'v': 71057550.0,
#   'vw': 125.3691,
#   'o': 126.17,
#   'c': 125.9,
#   'h': 126.32,
#   'l': 124.8321,
#   't': 1623038400000,
#   'n': 504254},
#  {'v': 74403774.0,
#   'vw': 127.0742,
#   'o': 126.6,
#   'c': 126.74,
#   'h': 128.46,
#   'l': 126.2101,
#   't': 1623124800000,
#   'n': 532078},
#  {'v': 56695219.0,
#   'vw': 127.0733,
#   'o': 127.21,
#   'c': 127.13,
#   'h': 127.75,
#   'l': 126.52,
#   't': 1623211200000,
#   'n': 382625},
#  {'v': 71186421.0,
#   'vw': 126.6607,
#   'o': 127.02,
#   'c': 126.11,
#   'h': 128.19,
#   'l': 125.94,
#   't': 1623297600000,
#   'n': 498371},
#  {'v': 53522373.0,
#   'vw': 127.0246,
#   'o': 126.53,
#   'c': 127.35,
#   'h': 127.44,
#   'l': 126.1,
#   't': 1623384000000,
#   'n': 354080},
#  {'v': 96906490.0,
#   'vw': 129.6322,
#   'o': 127.82,
#   'c': 130.48,
#   'h': 130.54,
#   'l': 127.07,
#   't': 1623643200000,
#   'n': 563595},
#  {'v': 62725532.0,
#   'vw': 129.8358,
#   'o': 129.94,
#   'c': 129.64,
#   'h': 130.6,
#   'l': 129.39,
#   't': 1623729600000,
#   'n': 416230},
#  {'v': 91793025.0,
#   'vw': 130.0001,
#   'o': 130.37,
#   'c': 130.15,
#   'h': 130.89,
#   'l': 128.461,
#   't': 1623816000000,
#   'n': 619028},
#  {'v': 96721669.0,
#   'vw': 131.5645,
#   'o': 129.8,
#   'c': 131.79,
#   'h': 132.55,
#   'l': 129.65,
#   't': 1623902400000,
#   'n': 652025},
#  {'v': 108890309.0,
#   'vw': 130.7868,
#   'o': 130.71,
#   'c': 130.46,
#   'h': 131.51,
#   'l': 130.24,
#   't': 1623988800000,
#   'n': 557039},
#  {'v': 79269216.0,
#   'vw': 131.4999,
#   'o': 130.3,
#   'c': 132.3,
#   'h': 132.41,
#   'l': 129.21,
#   't': 1624248000000,
#   'n': 506660},
#  {'v': 73713618.0,
#   'vw': 133.0905,
#   'o': 132.13,
#   'c': 133.98,
#   'h': 134.08,
#   'l': 131.62,
#   't': 1624334400000,
#   'n': 481082},
#  {'v': 60214200.0,
#   'vw': 133.7872,
#   'o': 133.77,
#   'c': 133.7,
#   'h': 134.32,
#   'l': 133.23,
#   't': 1624420800000,
#   'n': 424752},
#  {'v': 68710998.0,
#   'vw': 133.7663,
#   'o': 134.45,
#   'c': 133.41,
#   'h': 134.64,
#   'l': 132.93,
#   't': 1624507200000,
#   'n': 443492}]

# %%
results_df = pd.DataFrame(results)

# %%
results_df['t'] = (results_df['t']/1000)
results_df
# Out:
#                v        vw       o       c         h        l             t  \
# 0    143285672.0  129.7326  133.52  129.41  133.6116  126.760  1.609736e+09
# 1     97664898.0  130.7179  128.89  131.01  131.7400  128.430  1.609823e+09
# 2    155087970.0  128.3502  127.72  126.60  131.0499  126.382  1.609909e+09
# 3    109578157.0  130.1539  128.36  130.92  131.6300  127.860  1.609996e+09
# 4    105158245.0  131.5657  132.43  132.05  132.6300  130.230  1.610082e+09
# ..           ...       ...     ...     ...       ...      ...           ...
# 115  108890309.0  130.7868  130.71  130.46  131.5100  130.240  1.623989e+09
# 116   79269216.0  131.4999  130.30  132.30  132.4100  129.210  1.624248e+09
# 117   73713618.0  133.0905  132.13  133.98  134.0800  131.620  1.624334e+09
# 118   60214200.0  133.7872  133.77  133.70  134.3200  133.230  1.624421e+09
# 119   68710998.0  133.7663  134.45  133.41  134.6400  132.930  1.624507e+09
#
#            n
# 0    1310217
# 1     707577
# 2    1202574
# 3     718357
# 4     800069
# ..       ...
# 115   557039
# 116   506660
# 117   481082
# 118   424752
# 119   443492
#
# [120 rows x 8 columns]

# %%
close_over_2021 = results_df.plot.scatter(x='t', y='c', c='r')

# %%
results_df['date'] = pd.to_datetime(results_df['t'], unit='s')
results_df
# Out:
#                v        vw       o       c         h        l             t  \
# 0    143285672.0  129.7326  133.52  129.41  133.6116  126.760  1.609736e+09
# 1     97664898.0  130.7179  128.89  131.01  131.7400  128.430  1.609823e+09
# 2    155087970.0  128.3502  127.72  126.60  131.0499  126.382  1.609909e+09
# 3    109578157.0  130.1539  128.36  130.92  131.6300  127.860  1.609996e+09
# 4    105158245.0  131.5657  132.43  132.05  132.6300  130.230  1.610082e+09
# ..           ...       ...     ...     ...       ...      ...           ...
# 115  108890309.0  130.7868  130.71  130.46  131.5100  130.240  1.623989e+09
# 116   79269216.0  131.4999  130.30  132.30  132.4100  129.210  1.624248e+09
# 117   73713618.0  133.0905  132.13  133.98  134.0800  131.620  1.624334e+09
# 118   60214200.0  133.7872  133.77  133.70  134.3200  133.230  1.624421e+09
# 119   68710998.0  133.7663  134.45  133.41  134.6400  132.930  1.624507e+09
#
#            n                date
# 0    1310217 2021-01-04 05:00:00
# 1     707577 2021-01-05 05:00:00
# 2    1202574 2021-01-06 05:00:00
# 3     718357 2021-01-07 05:00:00
# 4     800069 2021-01-08 05:00:00
# ..       ...                 ...
# 115   557039 2021-06-18 04:00:00
# 116   506660 2021-06-21 04:00:00
# 117   481082 2021-06-22 04:00:00
# 118   424752 2021-06-23 04:00:00
# 119   443492 2021-06-24 04:00:00
#
# [120 rows x 9 columns]

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v       120 non-null    float64
#  1   vw      120 non-null    float64
#  2   o       120 non-null    float64
#  3   c       120 non-null    float64
#  4   h       120 non-null    float64
#  5   l       120 non-null    float64
#  6   t       120 non-null    float64
#  7   n       120 non-null    int64
#  8   date    120 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 8.6 KB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(25, 10))  # Create a figure containing a single axes.
ax.plot(results_df.date, results_df.c,  color='purple', linewidth=5)
ax.set_title('2021 Apple Cosing Value (AAPL)', fontsize=19)
ax.set_xlabel("Month", fontsize=17)
ax.set_ylabel("Value in US$", fontsize=17)
# Out:
# Text(0, 0.5, 'Value in US$')

# %%
import json
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine

from config import db_password

import time

# %%
df.columns
# Out:
# Index(['ticker', 'queryCount', 'resultsCount', 'adjusted', 'results', 'status',
#        'request_id', 'count'],
#       dtype='object')

# %%
df_to_postgres = df[['ticker', 'queryCount', 'resultsCount', 'adjusted', 'status',
                     'request_id', 'count']]

# %%
df_to_postgres.head()
# Out:
#   ticker  queryCount  resultsCount  adjusted status  \
# 0   AAPL         120           120      True     OK
# 1   AAPL         120           120      True     OK
# 2   AAPL         120           120      True     OK
# 3   AAPL         120           120      True     OK
# 4   AAPL         120           120      True     OK
#
#                          request_id  count
# 0  6c235020890f3ed81807b5b60c1f26f4    120
# 1  6c235020890f3ed81807b5b60c1f26f4    120
# 2  6c235020890f3ed81807b5b60c1f26f4    120
# 3  6c235020890f3ed81807b5b60c1f26f4    120
# 4  6c235020890f3ed81807b5b60c1f26f4    120

# %%
results_df.columns
# Out:
# Index(['v', 'vw', 'o', 'c', 'h', 'l', 't', 'n', 'date'], dtype='object')

# %%
results_df_to_sql = results_df[['v', 'vw', 'o', 'c', 'h', 'l', 'n', 'date']]
results_df_to_sql
# Out:
#                v        vw       o       c         h        l        n  \
# 0    143285672.0  129.7326  133.52  129.41  133.6116  126.760  1310217
# 1     97664898.0  130.7179  128.89  131.01  131.7400  128.430   707577
# 2    155087970.0  128.3502  127.72  126.60  131.0499  126.382  1202574
# 3    109578157.0  130.1539  128.36  130.92  131.6300  127.860   718357
# 4    105158245.0  131.5657  132.43  132.05  132.6300  130.230   800069
# ..           ...       ...     ...     ...       ...      ...      ...
# 115  108890309.0  130.7868  130.71  130.46  131.5100  130.240   557039
# 116   79269216.0  131.4999  130.30  132.30  132.4100  129.210   506660
# 117   73713618.0  133.0905  132.13  133.98  134.0800  131.620   481082
# 118   60214200.0  133.7872  133.77  133.70  134.3200  133.230   424752
# 119   68710998.0  133.7663  134.45  133.41  134.6400  132.930   443492
#
#                    date
# 0   2021-01-04 05:00:00
# 1   2021-01-05 05:00:00
# 2   2021-01-06 05:00:00
# 3   2021-01-07 05:00:00
# 4   2021-01-08 05:00:00
# ..                  ...
# 115 2021-06-18 04:00:00
# 116 2021-06-21 04:00:00
# 117 2021-06-22 04:00:00
# 118 2021-06-23 04:00:00
# 119 2021-06-24 04:00:00
#
# [120 rows x 8 columns]

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/final_project"

# %%
from sqlalchemy import create_engine
import psycopg2

engine = create_engine(db_string)

# %%
results_df_to_sql.to_sql(name='aapl_2021', con=engine)

# %%
df_to_postgres.to_sql(name='aapl_meta', con=engine)
